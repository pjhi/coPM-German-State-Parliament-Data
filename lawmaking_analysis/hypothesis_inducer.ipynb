# %% [markdown]
# # Notebook for Finding Process Outcome Explanations

# %% [markdown]
# ## Main Configuration

# %%
import pandas as pd
import numpy as np
import re

from rulelearn.algorithms.ripper import RipperExplainer
from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import precision_score, recall_score
from dtree_helper import get_rules

# %%
STRING_IMPUTE_VAL = 'missing'
FLOAT_IMPUTE_VAL = np.finfo(np.float32).min  # Imputation value for floats
TRAIN_TEST_SPLIT = 33  # Percentage of data to use for testing

BINA, ALGO =  'NATIVE', 'RIPPER'   # alternative: 'LENC', 'CART:4'  
# for other options, see: https://github.com/hvoelzer/rulebenchmarking

# %%
INPUT_FILE_NAME_BERLIN = 'cases_berlin-preprocessed-gesetzgebung-2006-2020_with_context.csv'
INPUT_FILE_NAME_BRANDENBURG = 'cases_brandenburg-preprocessed-gesetzgebung-2006-2020_processed_with_context.csv'
INPUT_FILE_NAME_BAWUE = 'cases_baden-württemberg-preprocessed-gesetzgebung-gesetz-2006-2020_processed_with_context.csv'
'''

INPUT_FILE_NAME_BERLIN = 'cases_berlin-preprocessed-gesetzgebung-2006-2020_with_context_passed_bills.csv'
INPUT_FILE_NAME_BRANDENBURG = 'cases_brandenburg-preprocessed-gesetzgebung-2006-2020_processed_with_context_passed_bills.csv'
INPUT_FILE_NAME_BAWUE = 'cases_baden-württemberg-preprocessed-gesetzgebung-gesetz-2006-2020_processed_with_context_passed_bills.csv'
'''

def read_and_sanitize(file_name):
    df = pd.read_csv(file_name, dtype={'is_passed_bill': object})
    print('Read', len(df), 'rows from', file_name)
    df.columns = df.columns.str.replace(r'[()]', '_', regex=True)
    df = df.dropna(axis=1, how='all')  # drop all completely empty columns
    return df

df_berlin = read_and_sanitize(INPUT_FILE_NAME_BERLIN)
df_brandenburg = read_and_sanitize(INPUT_FILE_NAME_BRANDENBURG)
df_baWue = read_and_sanitize(INPUT_FILE_NAME_BAWUE)

bawue_average_cycle_time = df_baWue["duration"].mean()
bawue_average_cycle_time_upper_bound = bawue_average_cycle_time + 0.1*bawue_average_cycle_time
bawue_average_cycle_time_lower_bound = bawue_average_cycle_time - 0.1*bawue_average_cycle_time
print(bawue_average_cycle_time_upper_bound)

print('Berlin:', len(df_berlin), 'Brandenburg:', len(df_brandenburg), 'BaWue:', len(df_baWue))
print('Mean duration values:')
print('Berlin:', df_berlin['duration'].mean())
print('Brandenburg:', df_brandenburg['duration'].mean())
print('BaWue:', df_baWue['duration'].mean())

outcome = lambda row: row['duration'] > bawue_average_cycle_time_upper_bound
# Out:
# Read 731 rows from cases_berlin-preprocessed-gesetzgebung-2006-2020_with_context.csv
# Read 718 rows from cases_brandenburg-preprocessed-gesetzgebung-2006-2020_processed_with_context.csv
# Read 1005 rows from cases_baden-württemberg-preprocessed-gesetzgebung-gesetz-2006-2020_processed_with_context.csv
# 67.05950248756218
# Berlin: 731 Brandenburg: 718 BaWue: 1005
# Mean duration values:
# Berlin: 176.33789329685362
# Brandenburg: 119.7883008356546
# BaWue: 60.96318407960199

# %%
# Prep data: cast all (remaining) Boolean columns as object and all Integer columns as float
for df in [df_berlin, df_brandenburg, df_baWue]:
    for column in df.select_dtypes(include=['bool']).columns:
        print(column, 'bool->object')
        df[column] = df[column].astype('object')
    for column in df.select_dtypes(include=['int64']).columns:
        print(column, 'int->float')
        df[column] = df[column].astype('float64')
    df.info(verbose=True)
# Out:
# case_id int->float
# event_count int->float
# start_time_rel int->float
# duration int->float
# case:start_month int->float
# case:start_weekday int->float
# case:WIP_during_start int->float
# case:pdf_bytes int->float
# case:pdf_word_count int->float
# case:plenDays int->float
# case:is_election_year int->float
# case:yearly_frequency int->float
# case:yearly_variants int->float
# case:author_first_activity_bündnis 90/die grünen _grüne_ int->float
# case:author_first_activity_nan int->float
# case:author_first_activity_ausschuss int->float
# case:author_first_activity_sozialdemokratische partei deutschlands _spd_ int->float
# case:author_first_activity_partei des demokratischen sozialismus _die linkspartei.pds_ int->float
# case:author_first_activity_freie demokratische partei _fdp_ int->float
# case:author_first_activity_christlich demokratische union deutschlands _cdu_ int->float
# case:author_first_activity_die linke fraktion berlin _die linke_ int->float
# case:author_first_activity_piraten _piraten_ int->float
# case:author_first_activity_alternative für deutschland _afd_ int->float
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 257 columns):
#  #    Column                                                                                                     Dtype
# ---   ------                                                                                                     -----
#  0    case_id                                                                                                    float64
#  1    Antrag _Gesetzentwurf_.count                                                                               float64
#  2    event_count                                                                                                float64
#  3    start_time                                                                                                 object
#  4    start_time_rel                                                                                             float64
#  5    duration                                                                                                   float64
#  6    Antrag _Gesetzentwurf_.start                                                                               float64
#  7    case:DokTypLFirstDoc                                                                                       object
#  8    case:VSysL                                                                                                 object
#  9    case:VorgangsDeskriptoren                                                                                  object
#  10   case:start_month                                                                                           float64
#  11   case:start_weekday                                                                                         float64
#  12   case:author_first_activity                                                                                 object
#  13   case:author_first_activity_count                                                                           float64
#  14   case:WIP_during_start                                                                                      float64
#  15   case:pdf_bytes                                                                                             float64
#  16   case:pdf_word_count                                                                                        float64
#  17   case:squire                                                                                                float64
#  18   case:salary                                                                                                float64
#  19   case:staff                                                                                                 float64
#  20   case:commDays                                                                                              float64
#  21   case:plenDays                                                                                              float64
#  22   case:af_score                                                                                              float64
#  23   case:is_election_year                                                                                      float64
#  24   case:yearly_frequency                                                                                      float64
#  25   case:yearly_cycle_time                                                                                     float64
#  26   case:yearly_arrival_rate                                                                                   float64
#  27   case:yearly_variants                                                                                       float64
#  28   case:author_first_activity_bündnis 90/die grünen _grüne_                                                   float64
#  29   case:author_first_activity_nan                                                                             float64
#  30   case:author_first_activity_ausschuss                                                                       float64
#  31   case:author_first_activity_sozialdemokratische partei deutschlands _spd_                                   float64
#  32   case:author_first_activity_partei des demokratischen sozialismus _die linkspartei.pds_                     float64
#  33   case:author_first_activity_freie demokratische partei _fdp_                                                float64
#  34   case:author_first_activity_christlich demokratische union deutschlands _cdu_                               float64
#  35   case:author_first_activity_die linke fraktion berlin _die linke_                                           float64
#  36   case:author_first_activity_piraten _piraten_                                                               float64
#  37   case:author_first_activity_alternative für deutschland _afd_                                               float64
#  38   I. Lesung.count                                                                                            float64
#  39   I. Lesung.start                                                                                            float64
#  40   Ausschussberatung.count                                                                                    float64
#  41   Ausschussberatung.start                                                                                    float64
#  42   Beschlussempfehlung.count                                                                                  float64
#  43   Beschlussempfehlung.start                                                                                  float64
#  44   II. Lesung.count                                                                                           float64
#  45   II. Lesung.start                                                                                           float64
#  46   Vorlage zur Beschlussfassung _Gesetzentwurf_.count                                                         float64
#  47   Vorlage zur Beschlussfassung _Gesetzentwurf_.start                                                         float64
#  48   Ausschussberatung:2.start                                                                                  float64
#  49   Gesetz- und Verordnungsblatt.count                                                                         float64
#  50   Gesetz- und Verordnungsblatt.start                                                                         float64
#  51   Gesetz- und Verordnungsblatt:2.start                                                                       float64
#  52   Ausschussberatung:3.start                                                                                  float64
#  53   Änderungsantrag.count                                                                                      float64
#  54   Änderungsantrag.start                                                                                      float64
#  55   Ausschussberatung:4.start                                                                                  float64
#  56   I. Lesung:2.start                                                                                          float64
#  57   Ausschussberatung:5.start                                                                                  float64
#  58   Ausschussberatung:6.start                                                                                  float64
#  59   Ausschussberatung:7.start                                                                                  float64
#  60   Ausschussberatung:8.start                                                                                  float64
#  61   III. Lesung.count                                                                                          float64
#  62   III. Lesung.start                                                                                          float64
#  63   Bekanntmachung _Gesetz- und Verordnungsblatt_.count                                                        float64
#  64   Bekanntmachung _Gesetz- und Verordnungsblatt_.start                                                        float64
#  65   Änderungsantrag:2.start                                                                                    float64
#  66   Gesetz- und Verordnungsblatt:3.start                                                                       float64
#  67   Neufassung.count                                                                                           float64
#  68   Neufassung.start                                                                                           float64
#  69   I. Lesung:3.start                                                                                          float64
#  70   Gesetz- und Verordnungsblatt:4.start                                                                       float64
#  71   Gesetz- und Verordnungsblatt:5.start                                                                       float64
#  72   Gesetz- und Verordnungsblatt:6.start                                                                       float64
#  73   Gesetz- und Verordnungsblatt:7.start                                                                       float64
#  74   Gesetz- und Verordnungsblatt:8.start                                                                       float64
#  75   Gesetz- und Verordnungsblatt:9.start                                                                       float64
#  76   Gesetz- und Verordnungsblatt:10.start                                                                      float64
#  77   Gesetz- und Verordnungsblatt:11.start                                                                      float64
#  78   Gesetz- und Verordnungsblatt:12.start                                                                      float64
#  79   Gesetz- und Verordnungsblatt:13.start                                                                      float64
#  80   Gesetz- und Verordnungsblatt:14.start                                                                      float64
#  81   Gesetz- und Verordnungsblatt:15.start                                                                      float64
#  82   Gesetz- und Verordnungsblatt:16.start                                                                      float64
#  83   Gesetz- und Verordnungsblatt:17.start                                                                      float64
#  84   Gesetz- und Verordnungsblatt:18.start                                                                      float64
#  85   I. Lesung:4.start                                                                                          float64
#  86   Behandlung im Plenum.count                                                                                 float64
#  87   Behandlung im Plenum.start                                                                                 float64
#  88   II. Lesung:2.start                                                                                         float64
#  89   Änderungsantrag:3.start                                                                                    float64
#  90   Vorlage zur Beschlussfassung _Gesetzentwurf_:2.start                                                       float64
#  91   Ausschussberatung:9.start                                                                                  float64
#  92   Ausschussberatung:10.start                                                                                 float64
#  93   Ausschussberatung:11.start                                                                                 float64
#  94   Ausschussberatung:12.start                                                                                 float64
#  95   Ausschussberatung:13.start                                                                                 float64
#  96   Ausschussberatung:14.start                                                                                 float64
#  97   Ausschussberatung:15.start                                                                                 float64
#  98   Ausschussberatung:16.start                                                                                 float64
#  99   Ausschussberatung:17.start                                                                                 float64
#  100  Ausschussberatung:18.start                                                                                 float64
#  101  Ausschussberatung:19.start                                                                                 float64
#  102  Ausschussberatung:20.start                                                                                 float64
#  103  Ausschussbesprechung.count                                                                                 float64
#  104  Ausschussbesprechung.start                                                                                 float64
#  105  Ausschussberatung:21.start                                                                                 float64
#  106  Ausschussberatung:22.start                                                                                 float64
#  107  Ausschussberatung:23.start                                                                                 float64
#  108  Ausschussberatung:24.start                                                                                 float64
#  109  Ausschussberatung:25.start                                                                                 float64
#  110  Ausschussberatung:26.start                                                                                 float64
#  111  Ausschussberatung:27.start                                                                                 float64
#  112  Ausschussberatung:28.start                                                                                 float64
#  113  Ausschussberatung:29.start                                                                                 float64
#  114  Ausschussberatung:30.start                                                                                 float64
#  115  Ausschussberatung:31.start                                                                                 float64
#  116  Ausschussberatung:32.start                                                                                 float64
#  117  Ausschussberatung:33.start                                                                                 float64
#  118  Ausschussberatung:34.start                                                                                 float64
#  119  Ausschussberatung:35.start                                                                                 float64
#  120  Ausschussberatung:36.start                                                                                 float64
#  121  Ausschussberatung:37.start                                                                                 float64
#  122  Ausschussberatung:38.start                                                                                 float64
#  123  Ausschussberatung:39.start                                                                                 float64
#  124  Ausschussberatung:40.start                                                                                 float64
#  125  Ausschussberatung:41.start                                                                                 float64
#  126  Ausschussberatung:42.start                                                                                 float64
#  127  Ausschussberatung:43.start                                                                                 float64
#  128  Ausschussberatung:44.start                                                                                 float64
#  129  Ausschussberatung:45.start                                                                                 float64
#  130  Ausschussberatung:46.start                                                                                 float64
#  131  Ausschussberatung:47.start                                                                                 float64
#  132  Ausschussberatung:48.start                                                                                 float64
#  133  Ausschussberatung:49.start                                                                                 float64
#  134  Ausschussberatung:50.start                                                                                 float64
#  135  Ausschussberatung:51.start                                                                                 float64
#  136  II. Lesung:3.start                                                                                         float64
#  137  II. Lesung:4.start                                                                                         float64
#  138  II. Lesung:5.start                                                                                         float64
#  139  II. Lesung:6.start                                                                                         float64
#  140  II. Lesung:7.start                                                                                         float64
#  141  II. Lesung:8.start                                                                                         float64
#  142  II. Lesung:9.start                                                                                         float64
#  143  II. Lesung:10.start                                                                                        float64
#  144  II. Lesung:11.start                                                                                        float64
#  145  II. Lesung:12.start                                                                                        float64
#  146  II. Lesung:13.start                                                                                        float64
#  147  II. Lesung:14.start                                                                                        float64
#  148  Vorlage zur Beschlussfassung.count                                                                         float64
#  149  Vorlage zur Beschlussfassung.start                                                                         float64
#  150  Gesetz- und Verordnungsblatt:19.start                                                                      float64
#  151  Gesetz- und Verordnungsblatt:20.start                                                                      float64
#  152  Gesetz- und Verordnungsblatt:21.start                                                                      float64
#  153  Gesetz- und Verordnungsblatt:22.start                                                                      float64
#  154  Gesetz- und Verordnungsblatt:23.start                                                                      float64
#  155  Gesetz- und Verordnungsblatt:24.start                                                                      float64
#  156  Gesetz- und Verordnungsblatt:25.start                                                                      float64
#  157  Ausschussbericht _Zwischenbericht_.count                                                                   float64
#  158  Ausschussbericht _Zwischenbericht_.start                                                                   float64
#  159  Ausschussberatung:52.start                                                                                 float64
#  160  Ausschussberatung:53.start                                                                                 float64
#  161  Ausschussberatung:54.start                                                                                 float64
#  162  Ausschussberatung:55.start                                                                                 float64
#  163  Änderungsantrag:4.start                                                                                    float64
#  164  Änderungsantrag:5.start                                                                                    float64
#  165  Änderungsantrag:6.start                                                                                    float64
#  166  Beschlussempfehlung:2.start                                                                                float64
#  167  Änderungsantrag:7.start                                                                                    float64
#  168  Änderungsantrag:8.start                                                                                    float64
#  169  Änderungsantrag:9.start                                                                                    float64
#  170  Änderungsantrag:10.start                                                                                   float64
#  171  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_.count                                               float64
#  172  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_.start                                               float64
#  173  Änderungsantrag:11.start                                                                                   float64
#  174  Änderungsantrag:12.start                                                                                   float64
#  175  Änderungsantrag:13.start                                                                                   float64
#  176  Änderungsantrag:14.start                                                                                   float64
#  177  Änderungsantrag:15.start                                                                                   float64
#  178  Änderungsantrag:16.start                                                                                   float64
#  179  Änderungsantrag:17.start                                                                                   float64
#  180  Änderungsantrag:18.start                                                                                   float64
#  181  Änderungsantrag:19.start                                                                                   float64
#  182  Änderungsantrag:20.start                                                                                   float64
#  183  Änderungsantrag:21.start                                                                                   float64
#  184  Änderungsantrag:22.start                                                                                   float64
#  185  III. Lesung:2.start                                                                                        float64
#  186  II. Lesung:15.start                                                                                        float64
#  187  Bekanntmachung _Gesetz- und Verordnungsblatt_:2.start                                                      float64
#  188  Ausschussbericht _Zwischenbericht_:Behandlung im Plenum.delay                                              float64
#  189  Ausschussbericht _Zwischenbericht_:Ausschussberatung.delay                                                 float64
#  190  Ausschussbericht _Zwischenbericht_:I. Lesung.delay                                                         float64
#  191  Ausschussbericht _Zwischenbericht_:Antrag _Gesetzentwurf_.delay                                            float64
#  192  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_:Behandlung im Plenum.delay                          float64
#  193  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_:Änderungsantrag.delay                               float64
#  194  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_:Gesetz- und Verordnungsblatt.delay                  float64
#  195  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_:II. Lesung.delay                                    float64
#  196  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_:Beschlussempfehlung.delay                           float64
#  197  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_:Ausschussberatung.delay                             float64
#  198  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_:I. Lesung.delay                                     float64
#  199  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay  float64
#  200  Vorlage zur Beschlussfassung:Gesetz- und Verordnungsblatt.delay                                            float64
#  201  Vorlage zur Beschlussfassung:II. Lesung.delay                                                              float64
#  202  Vorlage zur Beschlussfassung:Beschlussempfehlung.delay                                                     float64
#  203  Vorlage zur Beschlussfassung:Ausschussberatung.delay                                                       float64
#  204  Vorlage zur Beschlussfassung:I. Lesung.delay                                                               float64
#  205  Ausschussbesprechung:Änderungsantrag.delay                                                                 float64
#  206  Ausschussbesprechung:Gesetz- und Verordnungsblatt.delay                                                    float64
#  207  Ausschussbesprechung:II. Lesung.delay                                                                      float64
#  208  Ausschussbesprechung:Beschlussempfehlung.delay                                                             float64
#  209  Ausschussbesprechung:Ausschussberatung.delay                                                               float64
#  210  Ausschussbesprechung:I. Lesung.delay                                                                       float64
#  211  Ausschussbesprechung:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                                    float64
#  212  Behandlung im Plenum:III. Lesung.delay                                                                     float64
#  213  Behandlung im Plenum:Änderungsantrag.delay                                                                 float64
#  214  Behandlung im Plenum:Gesetz- und Verordnungsblatt.delay                                                    float64
#  215  Behandlung im Plenum:II. Lesung.delay                                                                      float64
#  216  Behandlung im Plenum:Beschlussempfehlung.delay                                                             float64
#  217  Behandlung im Plenum:Ausschussberatung.delay                                                               float64
#  218  Behandlung im Plenum:I. Lesung.delay                                                                       float64
#  219  Behandlung im Plenum:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                                    float64
#  220  Behandlung im Plenum:Antrag _Gesetzentwurf_.delay                                                          float64
#  221  Bekanntmachung _Gesetz- und Verordnungsblatt_:Gesetz- und Verordnungsblatt.delay                           float64
#  222  III. Lesung:Änderungsantrag.delay                                                                          float64
#  223  III. Lesung:Gesetz- und Verordnungsblatt.delay                                                             float64
#  224  III. Lesung:II. Lesung.delay                                                                               float64
#  225  III. Lesung:Beschlussempfehlung.delay                                                                      float64
#  226  III. Lesung:Ausschussberatung.delay                                                                        float64
#  227  III. Lesung:I. Lesung.delay                                                                                float64
#  228  III. Lesung:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                                             float64
#  229  Änderungsantrag:Gesetz- und Verordnungsblatt.delay                                                         float64
#  230  Änderungsantrag:II. Lesung.delay                                                                           float64
#  231  Änderungsantrag:Beschlussempfehlung.delay                                                                  float64
#  232  Änderungsantrag:Ausschussberatung.delay                                                                    float64
#  233  Änderungsantrag:I. Lesung.delay                                                                            float64
#  234  Änderungsantrag:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                                         float64
#  235  Änderungsantrag:Antrag _Gesetzentwurf_.delay                                                               float64
#  236  Gesetz- und Verordnungsblatt:II. Lesung.delay                                                              float64
#  237  Gesetz- und Verordnungsblatt:Beschlussempfehlung.delay                                                     float64
#  238  Gesetz- und Verordnungsblatt:Ausschussberatung.delay                                                       float64
#  239  Gesetz- und Verordnungsblatt:I. Lesung.delay                                                               float64
#  240  Gesetz- und Verordnungsblatt:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                            float64
#  241  Gesetz- und Verordnungsblatt:Antrag _Gesetzentwurf_.delay                                                  float64
#  242  II. Lesung:Beschlussempfehlung.delay                                                                       float64
#  243  II. Lesung:Ausschussberatung.delay                                                                         float64
#  244  II. Lesung:I. Lesung.delay                                                                                 float64
#  245  II. Lesung:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                                              float64
#  246  II. Lesung:Antrag _Gesetzentwurf_.delay                                                                    float64
#  247  Beschlussempfehlung:Ausschussberatung.delay                                                                float64
#  248  Beschlussempfehlung:I. Lesung.delay                                                                        float64
#  249  Beschlussempfehlung:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                                     float64
#  250  Beschlussempfehlung:Antrag _Gesetzentwurf_.delay                                                           float64
#  251  Ausschussberatung:I. Lesung.delay                                                                          float64
#  252  Ausschussberatung:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                                       float64
#  253  Ausschussberatung:Antrag _Gesetzentwurf_.delay                                                             float64
#  254  I. Lesung:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                                               float64
#  255  I. Lesung:Antrag _Gesetzentwurf_.delay                                                                     float64
#  256  is_passed_bill                                                                                             object
# dtypes: float64(251), object(6)
# memory usage: 1.4+ MB
# case_id int->float
# event_count int->float
# start_time_rel int->float
# duration int->float
# case:start_month int->float
# case:start_weekday int->float
# case:WIP_during_start int->float
# case:pdf_bytes int->float
# case:pdf_word_count int->float
# case:plenDays int->float
# case:is_election_year int->float
# case:author_first_activity_landesregierung int->float
# case:author_first_activity_die linkspartei.pds _die linkspartei.pds_ int->float
# case:author_first_activity_landtag int->float
# case:author_first_activity_ausschuss int->float
# case:author_first_activity_nan int->float
# case:author_first_activity_deutsche volksunion _dvu_ int->float
# case:author_first_activity_präsidium des landtages int->float
# case:author_first_activity_fritsch, gunter _präsident des landtages brandenburg_ int->float
# case:author_first_activity_sozialdemokratische partei deutschlands _spd_ int->float
# case:author_first_activity_christlich demokratische union deutschlands _cdu_ int->float
# case:author_first_activity_die linke _die linke_ int->float
# case:author_first_activity_[.lookup error 75] _cdu_ int->float
# case:author_first_activity_fraktion bündnis 90/die grünen _b90/grüne_ int->float
# case:author_first_activity_freie demokratische partei _fdp_ int->float
# case:author_first_activity_rat für sorbische _wendische_ angelegenheiten int->float
# case:author_first_activity_bischoff, mike _spd_ int->float
# case:author_first_activity_görke, christian _die linke_ int->float
# case:author_first_activity_halem, marie luise von _b90/grüne_ int->float
# case:author_first_activity_senftleben, ingo _cdu_ int->float
# case:author_first_activity_vogdt, marion _fdp_ int->float
# case:author_first_activity_enquete-kommission 5/2 int->float
# case:author_first_activity_kircheis, kerstin _spd_ int->float
# case:author_first_activity_lipsdorf, jens _fdp_ int->float
# case:author_first_activity_maresch, jürgen _die linke_ int->float
# case:author_first_activity_schier, roswitha _cdu_ int->float
# case:author_first_activity_schierack, prof. dr. michael _cdu_ int->float
# case:author_first_activity_schippel, werner-siegwart _spd_ int->float
# case:author_first_activity_schulz-höpfner, monika _cdu_ int->float
# case:author_first_activity_wöllert, birgit _die linke_ int->float
# case:author_first_activity_domres, thomas _die linke_ int->float
# case:author_first_activity_hoffmann, dr. gerd-rüdiger _fraktionslos_ int->float
# case:author_first_activity_stark, britta _präsidentin des landtages brandenburg_ int->float
# case:author_first_activity_vida, péter _fraktionslos_ int->float
# case:author_first_activity_alternative für deutschland _afd_ int->float
# case:author_first_activity_redmann, dr. jan _cdu_ int->float
# case:author_first_activity_nonnemacher, ursula _b90/grüne_ int->float
# case:author_first_activity_brandenburger vereinigte bürgerbewegungen / freie wähler gruppe _bvb / freie wähler gruppe_ int->float
# case:author_first_activity_rat für angelegenheiten der sorben/wenden int->float
# case:author_first_activity_schulze, christoph _fraktionslos_ int->float
# case:author_first_activity_schülzke, iris _fraktionslos_ int->float
# case:author_first_activity_enquete-kommission 6/1 int->float
# case:author_first_activity_lüttmann, björn _spd_ int->float
# case:author_first_activity_bommert, frank _cdu_ int->float
# case:author_first_activity_genilke, rainer _cdu_ int->float
# case:author_first_activity_lakenmacher, björn _cdu_ int->float
# case:author_first_activity_loehr, matthias _die linke_ int->float
# case:author_first_activity_liedtke, prof. dr. ulrike _präsidentin des landtages brandenburg_ int->float
# case:author_first_activity_brandenburger vereinigte bürgerbewegungen / freie wähler gruppe _bvb/fw_ int->float
# case:author_first_activity_bretz, steeven _cdu_ int->float
# case:author_first_activity_damus, sahra _b90/grüne_ int->float
# case:author_first_activity_keller, daniel _spd_ int->float
# case:author_first_activity_schäffer, marie _b90/grüne_ int->float
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 394 columns):
#  #    Column                                                                                                                  Dtype
# ---   ------                                                                                                                  -----
#  0    case_id                                                                                                                 float64
#  1    Gesetzentwurf.count                                                                                                     float64
#  2    event_count                                                                                                             float64
#  3    start_time                                                                                                              object
#  4    start_time_rel                                                                                                          float64
#  5    duration                                                                                                                float64
#  6    Gesetzentwurf.start                                                                                                     float64
#  7    case:DokTypLFirstDoc                                                                                                    object
#  8    case:VSysL                                                                                                              object
#  9    case:VorgangsDeskriptoren                                                                                               object
#  10   case:start_month                                                                                                        float64
#  11   case:start_weekday                                                                                                      float64
#  12   case:author_first_activity                                                                                              object
#  13   case:author_first_activity_count                                                                                        float64
#  14   case:WIP_during_start                                                                                                   float64
#  15   case:pdf_bytes                                                                                                          float64
#  16   case:pdf_word_count                                                                                                     float64
#  17   case:squire                                                                                                             float64
#  18   case:salary                                                                                                             float64
#  19   case:staff                                                                                                              float64
#  20   case:commDays                                                                                                           float64
#  21   case:plenDays                                                                                                           float64
#  22   case:af_score                                                                                                           float64
#  23   case:is_election_year                                                                                                   float64
#  24   case:yearly_frequency                                                                                                   float64
#  25   case:yearly_cycle_time                                                                                                  float64
#  26   case:yearly_arrival_rate                                                                                                float64
#  27   case:yearly_variants                                                                                                    float64
#  28   case:author_first_activity_landesregierung                                                                              float64
#  29   case:author_first_activity_die linkspartei.pds _die linkspartei.pds_                                                    float64
#  30   case:author_first_activity_landtag                                                                                      float64
#  31   case:author_first_activity_ausschuss                                                                                    float64
#  32   case:author_first_activity_nan                                                                                          float64
#  33   case:author_first_activity_deutsche volksunion _dvu_                                                                    float64
#  34   case:author_first_activity_präsidium des landtages                                                                      float64
#  35   case:author_first_activity_fritsch, gunter _präsident des landtages brandenburg_                                        float64
#  36   case:author_first_activity_sozialdemokratische partei deutschlands _spd_                                                float64
#  37   case:author_first_activity_christlich demokratische union deutschlands _cdu_                                            float64
#  38   case:author_first_activity_die linke _die linke_                                                                        float64
#  39   case:author_first_activity_[.lookup error 75] _cdu_                                                                     float64
#  40   case:author_first_activity_fraktion bündnis 90/die grünen _b90/grüne_                                                   float64
#  41   case:author_first_activity_freie demokratische partei _fdp_                                                             float64
#  42   case:author_first_activity_rat für sorbische _wendische_ angelegenheiten                                                float64
#  43   case:author_first_activity_bischoff, mike _spd_                                                                         float64
#  44   case:author_first_activity_görke, christian _die linke_                                                                 float64
#  45   case:author_first_activity_halem, marie luise von _b90/grüne_                                                           float64
#  46   case:author_first_activity_senftleben, ingo _cdu_                                                                       float64
#  47   case:author_first_activity_vogdt, marion _fdp_                                                                          float64
#  48   case:author_first_activity_enquete-kommission 5/2                                                                       float64
#  49   case:author_first_activity_kircheis, kerstin _spd_                                                                      float64
#  50   case:author_first_activity_lipsdorf, jens _fdp_                                                                         float64
#  51   case:author_first_activity_maresch, jürgen _die linke_                                                                  float64
#  52   case:author_first_activity_schier, roswitha _cdu_                                                                       float64
#  53   case:author_first_activity_schierack, prof. dr. michael _cdu_                                                           float64
#  54   case:author_first_activity_schippel, werner-siegwart _spd_                                                              float64
#  55   case:author_first_activity_schulz-höpfner, monika _cdu_                                                                 float64
#  56   case:author_first_activity_wöllert, birgit _die linke_                                                                  float64
#  57   case:author_first_activity_domres, thomas _die linke_                                                                   float64
#  58   case:author_first_activity_hoffmann, dr. gerd-rüdiger _fraktionslos_                                                    float64
#  59   case:author_first_activity_stark, britta _präsidentin des landtages brandenburg_                                        float64
#  60   case:author_first_activity_vida, péter _fraktionslos_                                                                   float64
#  61   case:author_first_activity_alternative für deutschland _afd_                                                            float64
#  62   case:author_first_activity_redmann, dr. jan _cdu_                                                                       float64
#  63   case:author_first_activity_nonnemacher, ursula _b90/grüne_                                                              float64
#  64   case:author_first_activity_brandenburger vereinigte bürgerbewegungen / freie wähler gruppe _bvb / freie wähler gruppe_  float64
#  65   case:author_first_activity_rat für angelegenheiten der sorben/wenden                                                    float64
#  66   case:author_first_activity_schulze, christoph _fraktionslos_                                                            float64
#  67   case:author_first_activity_schülzke, iris _fraktionslos_                                                                float64
#  68   case:author_first_activity_enquete-kommission 6/1                                                                       float64
#  69   case:author_first_activity_lüttmann, björn _spd_                                                                        float64
#  70   case:author_first_activity_bommert, frank _cdu_                                                                         float64
#  71   case:author_first_activity_genilke, rainer _cdu_                                                                        float64
#  72   case:author_first_activity_lakenmacher, björn _cdu_                                                                     float64
#  73   case:author_first_activity_loehr, matthias _die linke_                                                                  float64
#  74   case:author_first_activity_liedtke, prof. dr. ulrike _präsidentin des landtages brandenburg_                            float64
#  75   case:author_first_activity_brandenburger vereinigte bürgerbewegungen / freie wähler gruppe _bvb/fw_                     float64
#  76   case:author_first_activity_bretz, steeven _cdu_                                                                         float64
#  77   case:author_first_activity_damus, sahra _b90/grüne_                                                                     float64
#  78   case:author_first_activity_keller, daniel _spd_                                                                         float64
#  79   case:author_first_activity_schäffer, marie _b90/grüne_                                                                  float64
#  80   1. Lesung.count                                                                                                         float64
#  81   1. Lesung.start                                                                                                         float64
#  82   Sitzung.count                                                                                                           float64
# ...
#  355  Plenarprotokoll:Gesetzentwurf.delay                                                                                             float64
#  356  Antrag:Vorschlag.delay                                                                                                          float64
#  357  Antrag:Gesetz.delay                                                                                                             float64
#  358  Antrag:Gesetzesbeschluss des Landtags.delay                                                                                     float64
#  359  Antrag:Änderungsanträge _Sammeldrucksache_.delay                                                                                float64
#  360  Antrag:Zweite Beratung.delay                                                                                                    float64
#  361  Antrag:Entschließungsantrag.delay                                                                                               float64
#  362  Antrag:Änderungsantrag.delay                                                                                                    float64
#  363  Antrag:Änderungs- und Entschließungsanträge _Sammeldrucksache_.delay                                                            float64
#  364  Antrag:Mitteilung.delay                                                                                                         float64
#  365  Antrag:Beschlussempfehlung und Bericht.delay                                                                                    float64
#  366  Antrag:Erste Beratung.delay                                                                                                     float64
#  367  Antrag:Gesetzentwurf.delay                                                                                                      float64
#  368  Gesetzblatt für Baden-Württemberg:Vorschlag.delay                                                                               float64
#  369  Gesetzblatt für Baden-Württemberg:Gesetz.delay                                                                                  float64
#  370  Gesetzblatt für Baden-Württemberg:Gesetzesbeschluss des Landtags.delay                                                          float64
#  371  Gesetzblatt für Baden-Württemberg:Änderungsanträge _Sammeldrucksache_.delay                                                     float64
#  372  Gesetzblatt für Baden-Württemberg:Zweite Beratung.delay                                                                         float64
#  373  Gesetzblatt für Baden-Württemberg:Entschließungsantrag.delay                                                                    float64
#  374  Gesetzblatt für Baden-Württemberg:Änderungsantrag.delay                                                                         float64
#  375  Gesetzblatt für Baden-Württemberg:Beschlussempfehlung und Bericht.delay                                                         float64
#  376  Gesetzblatt für Baden-Württemberg:Erste Beratung.delay                                                                          float64
#  377  Gesetzblatt für Baden-Württemberg:Aktuelle Debatte.delay                                                                        float64
#  378  Gesetzblatt für Baden-Württemberg:Gesetzentwurf.delay                                                                           float64
#  379  Berichtigung des Gesetzes:Gesetz.delay                                                                                          float64
#  380  Berichtigung des Gesetzes:Gesetzesbeschluss des Landtags.delay                                                                  float64
#  381  Berichtigung des Gesetzes:Änderungsanträge _Sammeldrucksache_.delay                                                             float64
#  382  Berichtigung des Gesetzes:Zweite Beratung.delay                                                                                 float64
#  383  Berichtigung des Gesetzes:Entschließungsantrag.delay                                                                            float64
#  384  Berichtigung des Gesetzes:Änderungsantrag.delay                                                                                 float64
#  385  Berichtigung des Gesetzes:Beschlussempfehlung und Bericht.delay                                                                 float64
#  386  Berichtigung des Gesetzes:Erste Beratung.delay                                                                                  float64
#  387  Berichtigung des Gesetzes:Gesetzentwurf.delay                                                                                   float64
#  388  Vorschlag:Gesetz.delay                                                                                                          float64
#  389  Vorschlag:Gesetzesbeschluss des Landtags.delay                                                                                  float64
#  390  Vorschlag:Änderungsanträge _Sammeldrucksache_.delay                                                                             float64
#  391  Vorschlag:Zweite Beratung.delay                                                                                                 float64
#  392  Vorschlag:Entschließungsantrag.delay                                                                                            float64
#  393  Vorschlag:Änderungsantrag.delay                                                                                                 float64
#  394  Vorschlag:Änderungs- und Entschließungsanträge _Sammeldrucksache_.delay                                                         float64
#  395  Vorschlag:Mitteilung.delay                                                                                                      float64
#  396  Vorschlag:Beschlussempfehlung und Bericht.delay                                                                                 float64
#  397  Vorschlag:Erste Beratung.delay                                                                                                  float64
#  398  Vorschlag:Aktuelle Debatte.delay                                                                                                float64
#  399  Vorschlag:Gesetzentwurf.delay                                                                                                   float64
#  400  Gesetz:Gesetzesbeschluss des Landtags.delay                                                                                     float64
#  401  Gesetz:Änderungsanträge _Sammeldrucksache_.delay                                                                                float64
#  402  Gesetz:Zweite Beratung.delay                                                                                                    float64
#  403  Gesetz:Entschließungsantrag.delay                                                                                               float64
#  404  Gesetz:Änderungsantrag.delay                                                                                                    float64
#  405  Gesetz:Änderungs- und Entschließungsanträge _Sammeldrucksache_.delay                                                            float64
#  406  Gesetz:Mitteilung.delay                                                                                                         float64
#  407  Gesetz:Beschlussempfehlung und Bericht.delay                                                                                    float64
#  408  Gesetz:Erste Beratung.delay                                                                                                     float64
#  409  Gesetz:Aktuelle Debatte.delay                                                                                                   float64
#  410  Gesetz:Gesetzentwurf.delay                                                                                                      float64
#  411  Gesetzesbeschluss des Landtags:Änderungsanträge _Sammeldrucksache_.delay                                                        float64
#  412  Gesetzesbeschluss des Landtags:Zweite Beratung.delay                                                                            float64
#  413  Gesetzesbeschluss des Landtags:Entschließungsantrag.delay                                                                       float64
#  414  Gesetzesbeschluss des Landtags:Änderungsantrag.delay                                                                            float64
#  415  Gesetzesbeschluss des Landtags:Änderungs- und Entschließungsanträge _Sammeldrucksache_.delay                                    float64
#  416  Gesetzesbeschluss des Landtags:Mitteilung.delay                                                                                 float64
#  417  Gesetzesbeschluss des Landtags:Beschlussempfehlung und Bericht.delay                                                            float64
#  418  Gesetzesbeschluss des Landtags:Erste Beratung.delay                                                                             float64
#  419  Gesetzesbeschluss des Landtags:Aktuelle Debatte.delay                                                                           float64
#  420  Gesetzesbeschluss des Landtags:Gesetzentwurf.delay                                                                              float64
#  421  Änderungsanträge _Sammeldrucksache_:Zweite Beratung.delay                                                                       float64
#  422  Änderungsanträge _Sammeldrucksache_:Entschließungsantrag.delay                                                                  float64
#  423  Änderungsanträge _Sammeldrucksache_:Änderungsantrag.delay                                                                       float64
#  424  Änderungsanträge _Sammeldrucksache_:Änderungs- und Entschließungsanträge _Sammeldrucksache_.delay                               float64
#  425  Änderungsanträge _Sammeldrucksache_:Mitteilung.delay                                                                            float64
#  426  Änderungsanträge _Sammeldrucksache_:Beschlussempfehlung und Bericht.delay                                                       float64
#  427  Änderungsanträge _Sammeldrucksache_:Erste Beratung.delay                                                                        float64
#  428  Änderungsanträge _Sammeldrucksache_:Aktuelle Debatte.delay                                                                      float64
#  429  Änderungsanträge _Sammeldrucksache_:Gesetzentwurf.delay                                                                         float64
#  430  Zweite Beratung:Entschließungsantrag.delay                                                                                      float64
#  431  Zweite Beratung:Änderungsantrag.delay                                                                                           float64
#  432  Zweite Beratung:Änderungs- und Entschließungsanträge _Sammeldrucksache_.delay                                                   float64
#  433  Zweite Beratung:Mitteilung.delay                                                                                                float64
#  434  Zweite Beratung:Beschlussempfehlung und Bericht.delay                                                                           float64
#  435  Zweite Beratung:Erste Beratung.delay                                                                                            float64
#  436  Zweite Beratung:Aktuelle Debatte.delay                                                                                          float64
#  437  Zweite Beratung:Gesetzentwurf.delay                                                                                             float64
#  438  Entschließungsantrag:Änderungsantrag.delay                                                                                      float64
#  439  Entschließungsantrag:Änderungs- und Entschließungsanträge _Sammeldrucksache_.delay                                              float64
#  440  Entschließungsantrag:Mitteilung.delay                                                                                           float64
#  441  Entschließungsantrag:Beschlussempfehlung und Bericht.delay                                                                      float64
#  442  Entschließungsantrag:Erste Beratung.delay                                                                                       float64
#  443  Entschließungsantrag:Aktuelle Debatte.delay                                                                                     float64
#  444  Entschließungsantrag:Gesetzentwurf.delay                                                                                        float64
#  445  Änderungsantrag:Änderungs- und Entschließungsanträge _Sammeldrucksache_.delay                                                   float64
#  446  Änderungsantrag:Mitteilung.delay                                                                                                float64
#  447  Änderungsantrag:Beschlussempfehlung und Bericht.delay                                                                           float64
#  448  Änderungsantrag:Erste Beratung.delay                                                                                            float64
#  449  Änderungsantrag:Aktuelle Debatte.delay                                                                                          float64
#  450  Änderungsantrag:Gesetzentwurf.delay                                                                                             float64
#  451  Änderungs- und Entschließungsanträge _Sammeldrucksache_:Mitteilung.delay                                                        float64
#  452  Änderungs- und Entschließungsanträge _Sammeldrucksache_:Beschlussempfehlung und Bericht.delay                                   float64
#  453  Änderungs- und Entschließungsanträge _Sammeldrucksache_:Erste Beratung.delay                                                    float64
#  454  Änderungs- und Entschließungsanträge _Sammeldrucksache_:Aktuelle Debatte.delay                                                  float64
#  455  Änderungs- und Entschließungsanträge _Sammeldrucksache_:Gesetzentwurf.delay                                                     float64
#  456  Mitteilung:Beschlussempfehlung und Bericht.delay                                                                                float64
#  457  Mitteilung:Erste Beratung.delay                                                                                                 float64
#  458  Mitteilung:Aktuelle Debatte.delay                                                                                               float64
#  459  Mitteilung:Gesetzentwurf.delay                                                                                                  float64
#  460  Beschlussempfehlung und Bericht:Erste Beratung.delay                                                                            float64
#  461  Beschlussempfehlung und Bericht:Aktuelle Debatte.delay                                                                          float64
#  462  Beschlussempfehlung und Bericht:Gesetzentwurf.delay                                                                             float64
#  463  Erste Beratung:Aktuelle Debatte.delay                                                                                           float64
#  464  Erste Beratung:Gesetzentwurf.delay                                                                                              float64
#  465  Aktuelle Debatte:Gesetzentwurf.delay                                                                                            float64
#  466  is_passed_bill                                                                                                                  object
# dtypes: float64(461), object(6)
# memory usage: 3.6+ MB

# %%
# Prep data: Imputation whenever needed
for df in [df_berlin, df_brandenburg, df_baWue]:
    for column in df.select_dtypes(include=['object']).columns:
        df[column] = df[column].fillna(STRING_IMPUTE_VAL)  # normalize missing string values
    if ALGO in ['CART:4'] or BINA in ['TREES']:
        for column in df.select_dtypes(include=['float64']).columns:
            df[column] = df[column].fillna(FLOAT_IMPUTE_VAL)

# %% [markdown]
# ## Configuration of the Explanation Problem

# %%
POS_CLASS = True
df_berlin['outcome'] = df_berlin.apply(outcome, axis=1)
df_brandenburg['outcome'] = df_brandenburg.apply(outcome, axis=1)
df_baWue['outcome'] = df_baWue.apply(outcome, axis=1)

# %% [markdown]
# ### Attribute Hiding

# %%
# Use attribute names or regular expressions to hide
HIDE = [
    
    # hide what we want to explain
    'duration',
    r'.*cycle.*',
    
    # hide meaningless columns
    'case_id',
    r'.*none.*',
    r'.*nan.*',
    

        
    # temporal columns
    'start_time_rel',
    'start_time', 
    r'.*start.*', 
    #r'.*delay.*',
    
    r'.*Geset.*',

    # experiments
    #r'.*count.*',

    #"is_passed_bill",
    
    #r'.*:[0-9].*',

    ]

for df in [df_berlin, df_brandenburg, df_baWue]:
    for pattern in HIDE:
        for col in df.columns:
            if re.fullmatch(pattern, col):
                # print('Dropping {} on pattern "{}".'.format(col, pattern))
                df.drop(columns=[col], inplace=True)

# %% [markdown]
# ## Run Rule Induction

# %%
stateParliaments = ['Berlin', 'Brandenburg', 'BaWue']
for index, df in enumerate([df_berlin, df_brandenburg, df_baWue]):    
    print(f"\nHandling dataset: {stateParliaments[index]}\n")
    
    # Prep data: Split into training and test set
    if TRAIN_TEST_SPLIT > 0.0:
        x_train, x_test, y_train, y_test = train_test_split(
            df.drop(columns=['outcome']),
            df['outcome'],
            test_size=TRAIN_TEST_SPLIT,
            random_state=3) 
    else:
        x_train = df.drop(columns=['outcome'])
        y_train = df['outcome']
        x_test = x_train
        y_test = y_train
    
    
    # Run Binarizer / Encoding
    if BINA == 'LENC':
        x_train_bin = x_train
        x_test_bin = x_test
        categorical_features = x_train_bin.select_dtypes(include=['object']).columns
        for col in categorical_features:
            label_encoder = LabelEncoder()
            label_encoder = label_encoder.fit(df[col])
            x_train_bin[col] = label_encoder.transform(x_train_bin[col])
            x_test_bin[col] = label_encoder.transform(x_test_bin[col])
            print(col, label_encoder.classes_, label_encoder.transform(label_encoder.classes_))
    elif BINA == 'NATIVE':
        x_train_bin = x_train.copy() # RIPPER implementation messes with the training set
        x_test_bin = x_test
        
    if ALGO == 'RIPPER':
        estimator = RipperExplainer()
        estimator.fit(x_train_bin, y_train, target_label=POS_CLASS)
    else:
        print('Not supported.')
        
    
    # Evaluation
    y_predicted = estimator.predict(x_test_bin)
    # print('Accuracy:', round(accuracy_score(y_test, y_predicted), 2))
    print('Predictive:')
    print('Precision:', round(precision_score(y_test, y_predicted, pos_label=POS_CLASS, zero_division=1), 6))
    print('Recall:', round(recall_score(y_test, y_predicted, pos_label=POS_CLASS), 6))
    y_predicted_train = estimator.predict(x_train_bin)
    print('Descriptive:')
    print('Precision:', round(precision_score(y_train, y_predicted_train, pos_label=POS_CLASS, zero_division=1), 6))
    print('Recall:', round(recall_score(y_train, y_predicted_train, pos_label=POS_CLASS), 6))
    
    

    # Model export
    print("bawue_average_cycle_time_upper_bound:", bawue_average_cycle_time_upper_bound)
    if ALGO in ('RIPPER'):
        rule_set = estimator.explain()
        print(rule_set)
# Out:
# Handling dataset: Berlin
#
# Predictive:
# Precision: 0.952381
# Recall: 0.769231
# Descriptive:
# Precision: 0.988235
# Recall: 0.919037
# bawue_average_cycle_time_upper_bound: 67.05950248756218
# if
# ([II. Lesung:Ausschussberatung.delay <= -45.0]) v
# ([Beschlussempfehlung:I. Lesung.delay <= -24.0] ^ [II. Lesung:I. Lesung.delay <= -49.0]) v
# ([event_count >= 8.0] ^ [Änderungsantrag.count <= 0.0] ^ [Ausschussberatung.count <= 2.0]) v
# ([event_count >= 7.0] ^ [Ausschussberatung.count <= 1.0] ^ [Änderungsantrag.count <= 0.0])
# then
# True
#
# Handling dataset: Brandenburg
#
# Predictive:
# Precision: 1.0
# Recall: 0.952381
# Descriptive:
# Precision: 0.961538
# Recall: 0.988372
# bawue_average_cycle_time_upper_bound: 67.05950248756218
# if
# ([case:author_first_activity == Landesregierung] ^ [case:pdf_bytes >= 1056500.0]) v
# ([event_count >= 5.0] ^ [Beschlussempfehlung und Bericht:Sitzung.delay <= -65.0]) v
# ([2. Lesung:1. Lesung.delay <= -27.0] ^ [Bekanntmachung.count >= 1.0]) v
# ([2. Lesung:1. Lesung.delay <= -42.0]) v
# ([Beschlussempfehlung und Bericht:1. Lesung.delay <= -22.0] ^ [event_count <= 6.0] ^ [2. Lesung:1. Lesung.delay >= -30.0]) v
# ([Beschlussempfehlung und Bericht:Sitzung.delay <= -63.0]) v
# ([2. Lesung:1. Lesung.delay <= -34.0] ^ [case:author_first_activity_count <= 2.0]) v
# ([case:VSysL == ['Abgaben', 'Erneuerbare Energien']]) v
# ([2. Lesung:Bekanntmachung.delay >= 13.0])
# then
# True
#
# Handling dataset: BaWue
#
# Predictive:
# Precision: 0.833333
# Recall: 0.833333
# Descriptive:
# Precision: 0.920792
# Recall: 0.664286
# bawue_average_cycle_time_upper_bound: 67.05950248756218
# if
# ([Erste Beratung.count >= 1.0] ^ [Beschlussempfehlung und Bericht:Erste Beratung.delay <= -42.0]) v
# ([case:DokTypLFirstDoc == Gesetzentwurf] ^ [Änderungsantrag:Beschlussempfehlung und Bericht.delay <= -14.0] ^ [case:yearly_arrival_rate >= 5.69] ^ [case:pdf_bytes >= 150592.0] ^ [case:salary <= 7671.4833984375]) v
# ([Mitteilung.count >= 1.0]) v
# ([case:author_first_activity_count <= 1.0] ^ [case:staff <= 81648.8046875] ^ [is_passed_bill == False]) v
# ([Zweite Beratung:Erste Beratung.delay <= -41.0]) v
# ([Beschlussempfehlung und Bericht:Erste Beratung.delay >= -15.0] ^ [case:pdf_word_count >= 32950.0] ^ [case:pdf_bytes >= 371742.0]) v
# ([Zweite Beratung:Erste Beratung.delay >= -36.0] ^ [Bekanntmachung:Zweite Beratung.delay <= -51.0])
# then
# True
