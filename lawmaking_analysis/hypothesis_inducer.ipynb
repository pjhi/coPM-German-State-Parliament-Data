# %% [markdown]
# # Notebook for Finding Process Outcome Explanations

# %% [markdown]
# ## Main Configuration

# %%
import pandas as pd
import numpy as np
import re

from rulelearn.algorithms.ripper import RipperExplainer
from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import precision_score, recall_score
from dtree_helper import get_rules

# %%
STRING_IMPUTE_VAL = 'missing'
FLOAT_IMPUTE_VAL = np.finfo(np.float32).min  # Imputation value for floats
TRAIN_TEST_SPLIT = 33  # Percentage of data to use for testing

BINA, ALGO =  'NATIVE', 'RIPPER'   # alternative: 'LENC', 'CART:4'  
# for other options, see: https://github.com/hvoelzer/rulebenchmarking

# %%
INPUT_FILE_NAME_BERLIN = 'cases_berlin-preprocessed-gesetzgebung-2006-2020_with_context.csv'
INPUT_FILE_NAME_BRANDENBURG = 'cases_brandenburg-preprocessed-gesetzgebung-2006-2020_processed_with_context.csv'
INPUT_FILE_NAME_BAWUE = 'cases_baden-württemberg-preprocessed-gesetzgebung-gesetz-2006-2020_processed_with_context.csv'
'''

INPUT_FILE_NAME_BERLIN = 'cases_berlin-preprocessed-gesetzgebung-2006-2020_with_context_passed_bills.csv'
INPUT_FILE_NAME_BRANDENBURG = 'cases_brandenburg-preprocessed-gesetzgebung-2006-2020_processed_with_context_passed_bills.csv'
INPUT_FILE_NAME_BAWUE = 'cases_baden-württemberg-preprocessed-gesetzgebung-gesetz-2006-2020_processed_with_context_passed_bills.csv'
'''

def read_and_sanitize(file_name):
    df = pd.read_csv(file_name, dtype={'case:is_passed_bill': object})
    print('Read', len(df), 'rows from', file_name)
    df.columns = df.columns.str.replace(r'[()]', '_', regex=True)
    df = df.dropna(axis=1, how='all')  # drop all completely empty columns
    return df

df_berlin = read_and_sanitize(INPUT_FILE_NAME_BERLIN)
df_brandenburg = read_and_sanitize(INPUT_FILE_NAME_BRANDENBURG)
df_baWue = read_and_sanitize(INPUT_FILE_NAME_BAWUE)

bawue_average_cycle_time = df_baWue["duration"].mean()
bawue_average_cycle_time_upper_bound = bawue_average_cycle_time + 0.1*bawue_average_cycle_time
bawue_average_cycle_time_lower_bound = bawue_average_cycle_time - 0.1*bawue_average_cycle_time
print(bawue_average_cycle_time_upper_bound)

print('Berlin:', len(df_berlin), 'Brandenburg:', len(df_brandenburg), 'BaWue:', len(df_baWue))
print('Mean duration values:')
print('Berlin:', df_berlin['duration'].mean())
print('Brandenburg:', df_brandenburg['duration'].mean())
print('BaWue:', df_baWue['duration'].mean())

outcome = lambda row: row['duration'] > bawue_average_cycle_time_upper_bound
# Out:
# Read 550 rows from cases_berlin-preprocessed-gesetzgebung-2006-2020_with_context.csv
# Read 439 rows from cases_brandenburg-preprocessed-gesetzgebung-2006-2020_processed_with_context.csv
# Read 312 rows from cases_baden-württemberg-preprocessed-gesetzgebung-gesetz-2006-2020_processed_with_context.csv
# 100.68525641025641
# Berlin: 550 Brandenburg: 439 BaWue: 312
# Mean duration values:
# Berlin: 123.58363636363636
# Brandenburg: 156.1617312072893
# BaWue: 91.53205128205128

# %%
# Prep data: cast all (remaining) Boolean columns as object and all Integer columns as float
for df in [df_berlin, df_brandenburg, df_baWue]:
    for column in df.select_dtypes(include=['bool']).columns:
        print(column, 'bool->object')
        df[column] = df[column].astype('object')
    for column in df.select_dtypes(include=['int64']).columns:
        print(column, 'int->float')
        df[column] = df[column].astype('float64')
    df.info(verbose=True)
# Out:
# case_id int->float
# event_count int->float
# start_time_rel int->float
# duration int->float
# case:start_month int->float
# case:start_weekday int->float
# case:WIP_during_start int->float
# case:pdf_bytes int->float
# case:pdf_word_count int->float
# case:plenDays int->float
# case:is_election_year int->float
# case:yearly_frequency int->float
# case:yearly_variants int->float
# case:author_first_activity_bündnis 90/die grünen _grüne_ int->float
# case:author_first_activity_nan int->float
# case:author_first_activity_ausschuss int->float
# case:author_first_activity_sozialdemokratische partei deutschlands _spd_ int->float
# case:author_first_activity_partei des demokratischen sozialismus _die linkspartei.pds_ int->float
# case:author_first_activity_freie demokratische partei _fdp_ int->float
# case:author_first_activity_christlich demokratische union deutschlands _cdu_ int->float
# case:author_first_activity_die linke fraktion berlin _die linke_ int->float
# case:author_first_activity_piraten _piraten_ int->float
# case:author_first_activity_alternative für deutschland _afd_ int->float
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 247 columns):
#  #    Column                                                                                                     Dtype
# ---   ------                                                                                                     -----
#  0    case_id                                                                                                    float64
#  1    Vorlage zur Beschlussfassung _Gesetzentwurf_.count                                                         float64
#  2    event_count                                                                                                float64
#  3    start_time                                                                                                 object
#  4    start_time_rel                                                                                             float64
#  5    duration                                                                                                   float64
#  6    Vorlage zur Beschlussfassung _Gesetzentwurf_.start                                                         float64
#  7    case:DokTypLFirstDoc                                                                                       object
#  8    case:VSysL                                                                                                 object
#  9    case:VorgangsDeskriptoren                                                                                  object
#  10   case:start_month                                                                                           float64
#  11   case:start_weekday                                                                                         float64
#  12   case:author_first_activity                                                                                 object
#  13   case:WIP_during_start                                                                                      float64
#  14   case:pdf_bytes                                                                                             float64
#  15   case:pdf_word_count                                                                                        float64
#  16   case:squire                                                                                                float64
#  17   case:salary                                                                                                float64
#  18   case:staff                                                                                                 float64
#  19   case:commDays                                                                                              float64
#  20   case:plenDays                                                                                              float64
#  21   case:af_score                                                                                              float64
#  22   case:is_passed_bill                                                                                        object
#  23   case:is_election_year                                                                                      float64
#  24   case:yearly_frequency                                                                                      float64
#  25   case:yearly_cycle_time                                                                                     float64
#  26   case:yearly_arrival_rate                                                                                   float64
#  27   case:yearly_variants                                                                                       float64
#  28   case:author_first_activity_bündnis 90/die grünen _grüne_                                                   float64
#  29   case:author_first_activity_nan                                                                             float64
#  30   case:author_first_activity_ausschuss                                                                       float64
#  31   case:author_first_activity_sozialdemokratische partei deutschlands _spd_                                   float64
#  32   case:author_first_activity_partei des demokratischen sozialismus _die linkspartei.pds_                     float64
#  33   case:author_first_activity_freie demokratische partei _fdp_                                                float64
#  34   case:author_first_activity_christlich demokratische union deutschlands _cdu_                               float64
#  35   case:author_first_activity_die linke fraktion berlin _die linke_                                           float64
#  36   case:author_first_activity_piraten _piraten_                                                               float64
#  37   case:author_first_activity_alternative für deutschland _afd_                                               float64
#  38   I. Lesung.count                                                                                            float64
#  39   I. Lesung.start                                                                                            float64
#  40   Ausschussberatung.count                                                                                    float64
#  41   Ausschussberatung.start                                                                                    float64
#  42   Ausschussberatung:2.start                                                                                  float64
#  43   Beschlussempfehlung.count                                                                                  float64
#  44   Beschlussempfehlung.start                                                                                  float64
#  45   II. Lesung.count                                                                                           float64
#  46   II. Lesung.start                                                                                           float64
#  47   Gesetz- und Verordnungsblatt.count                                                                         float64
#  48   Gesetz- und Verordnungsblatt.start                                                                         float64
#  49   Gesetz- und Verordnungsblatt:2.start                                                                       float64
#  50   Antrag _Gesetzentwurf_.count                                                                               float64
#  51   Antrag _Gesetzentwurf_.start                                                                               float64
#  52   case:author_first_activity_count                                                                           float64
#  53   Ausschussberatung:3.start                                                                                  float64
#  54   Änderungsantrag.count                                                                                      float64
#  55   Änderungsantrag.start                                                                                      float64
#  56   Ausschussberatung:4.start                                                                                  float64
#  57   I. Lesung:2.start                                                                                          float64
#  58   Ausschussberatung:5.start                                                                                  float64
#  59   Ausschussberatung:6.start                                                                                  float64
#  60   Ausschussberatung:7.start                                                                                  float64
#  61   Ausschussberatung:8.start                                                                                  float64
#  62   III. Lesung.count                                                                                          float64
#  63   III. Lesung.start                                                                                          float64
#  64   Bekanntmachung _Gesetz- und Verordnungsblatt_.count                                                        float64
#  65   Bekanntmachung _Gesetz- und Verordnungsblatt_.start                                                        float64
#  66   Änderungsantrag:2.start                                                                                    float64
#  67   Gesetz- und Verordnungsblatt:3.start                                                                       float64
#  68   Gesetz- und Verordnungsblatt:4.start                                                                       float64
#  69   Gesetz- und Verordnungsblatt:5.start                                                                       float64
#  70   Gesetz- und Verordnungsblatt:6.start                                                                       float64
#  71   Gesetz- und Verordnungsblatt:7.start                                                                       float64
#  72   Gesetz- und Verordnungsblatt:8.start                                                                       float64
#  73   Gesetz- und Verordnungsblatt:9.start                                                                       float64
#  74   Gesetz- und Verordnungsblatt:10.start                                                                      float64
#  75   Gesetz- und Verordnungsblatt:11.start                                                                      float64
#  76   Gesetz- und Verordnungsblatt:12.start                                                                      float64
#  77   Gesetz- und Verordnungsblatt:13.start                                                                      float64
#  78   Gesetz- und Verordnungsblatt:14.start                                                                      float64
#  79   Gesetz- und Verordnungsblatt:15.start                                                                      float64
#  80   Gesetz- und Verordnungsblatt:16.start                                                                      float64
#  81   Gesetz- und Verordnungsblatt:17.start                                                                      float64
#  82   Gesetz- und Verordnungsblatt:18.start                                                                      float64
#  83   Änderungsantrag:3.start                                                                                    float64
#  84   Behandlung im Plenum.count                                                                                 float64
#  85   Behandlung im Plenum.start                                                                                 float64
#  86   Vorlage zur Beschlussfassung _Gesetzentwurf_:2.start                                                       float64
#  87   Ausschussberatung:9.start                                                                                  float64
#  88   Ausschussberatung:10.start                                                                                 float64
#  89   Ausschussberatung:11.start                                                                                 float64
#  90   Ausschussberatung:12.start                                                                                 float64
#  91   Ausschussberatung:13.start                                                                                 float64
#  92   Ausschussberatung:14.start                                                                                 float64
#  93   Ausschussberatung:15.start                                                                                 float64
#  94   Ausschussberatung:16.start                                                                                 float64
#  95   Ausschussberatung:17.start                                                                                 float64
#  96   Ausschussberatung:18.start                                                                                 float64
#  97   Ausschussberatung:19.start                                                                                 float64
#  98   Ausschussbesprechung.count                                                                                 float64
#  99   Ausschussbesprechung.start                                                                                 float64
#  100  Ausschussberatung:20.start                                                                                 float64
#  101  Ausschussberatung:21.start                                                                                 float64
#  102  Ausschussberatung:22.start                                                                                 float64
#  103  Ausschussberatung:23.start                                                                                 float64
#  104  Ausschussberatung:24.start                                                                                 float64
#  105  Ausschussberatung:25.start                                                                                 float64
#  106  Ausschussberatung:26.start                                                                                 float64
#  107  Ausschussberatung:27.start                                                                                 float64
#  108  Ausschussberatung:28.start                                                                                 float64
#  109  Ausschussberatung:29.start                                                                                 float64
#  110  Ausschussberatung:30.start                                                                                 float64
#  111  Ausschussberatung:31.start                                                                                 float64
#  112  Ausschussberatung:32.start                                                                                 float64
#  113  Ausschussberatung:33.start                                                                                 float64
#  114  Ausschussberatung:34.start                                                                                 float64
#  115  Ausschussberatung:35.start                                                                                 float64
#  116  Ausschussberatung:36.start                                                                                 float64
#  117  Ausschussberatung:37.start                                                                                 float64
#  118  Ausschussberatung:38.start                                                                                 float64
#  119  Ausschussberatung:39.start                                                                                 float64
#  120  Ausschussberatung:40.start                                                                                 float64
#  121  Ausschussberatung:41.start                                                                                 float64
#  122  Ausschussberatung:42.start                                                                                 float64
#  123  Ausschussberatung:43.start                                                                                 float64
#  124  Ausschussberatung:44.start                                                                                 float64
#  125  Ausschussberatung:45.start                                                                                 float64
#  126  Ausschussberatung:46.start                                                                                 float64
#  127  Ausschussberatung:47.start                                                                                 float64
#  128  Ausschussberatung:48.start                                                                                 float64
#  129  Ausschussberatung:49.start                                                                                 float64
#  130  Ausschussberatung:50.start                                                                                 float64
#  131  Ausschussberatung:51.start                                                                                 float64
#  132  II. Lesung:2.start                                                                                         float64
#  133  II. Lesung:3.start                                                                                         float64
#  134  II. Lesung:4.start                                                                                         float64
#  135  II. Lesung:5.start                                                                                         float64
#  136  II. Lesung:6.start                                                                                         float64
#  137  II. Lesung:7.start                                                                                         float64
#  138  II. Lesung:8.start                                                                                         float64
#  139  II. Lesung:9.start                                                                                         float64
#  140  II. Lesung:10.start                                                                                        float64
#  141  II. Lesung:11.start                                                                                        float64
#  142  II. Lesung:12.start                                                                                        float64
#  143  II. Lesung:13.start                                                                                        float64
#  144  II. Lesung:14.start                                                                                        float64
#  145  Vorlage zur Beschlussfassung.count                                                                         float64
#  146  Vorlage zur Beschlussfassung.start                                                                         float64
#  147  Gesetz- und Verordnungsblatt:19.start                                                                      float64
#  148  Gesetz- und Verordnungsblatt:20.start                                                                      float64
#  149  Gesetz- und Verordnungsblatt:21.start                                                                      float64
#  150  Gesetz- und Verordnungsblatt:22.start                                                                      float64
#  151  Gesetz- und Verordnungsblatt:23.start                                                                      float64
#  152  Gesetz- und Verordnungsblatt:24.start                                                                      float64
#  153  Gesetz- und Verordnungsblatt:25.start                                                                      float64
#  154  Ausschussberatung:52.start                                                                                 float64
#  155  Ausschussberatung:53.start                                                                                 float64
#  156  Ausschussberatung:54.start                                                                                 float64
#  157  Ausschussberatung:55.start                                                                                 float64
#  158  Änderungsantrag:4.start                                                                                    float64
#  159  Änderungsantrag:5.start                                                                                    float64
#  160  Änderungsantrag:6.start                                                                                    float64
#  161  Beschlussempfehlung:2.start                                                                                float64
#  162  Änderungsantrag:7.start                                                                                    float64
#  163  Änderungsantrag:8.start                                                                                    float64
#  164  Änderungsantrag:9.start                                                                                    float64
#  165  Änderungsantrag:10.start                                                                                   float64
#  166  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_.count                                               float64
#  167  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_.start                                               float64
#  168  Änderungsantrag:11.start                                                                                   float64
#  169  Änderungsantrag:12.start                                                                                   float64
#  170  Änderungsantrag:13.start                                                                                   float64
#  171  Änderungsantrag:14.start                                                                                   float64
#  172  Änderungsantrag:15.start                                                                                   float64
#  173  Änderungsantrag:16.start                                                                                   float64
#  174  Änderungsantrag:17.start                                                                                   float64
#  175  Änderungsantrag:18.start                                                                                   float64
#  176  Änderungsantrag:19.start                                                                                   float64
#  177  Änderungsantrag:20.start                                                                                   float64
#  178  Änderungsantrag:21.start                                                                                   float64
#  179  Änderungsantrag:22.start                                                                                   float64
#  180  III. Lesung:2.start                                                                                        float64
#  181  II. Lesung:15.start                                                                                        float64
#  182  Bekanntmachung _Gesetz- und Verordnungsblatt_:2.start                                                      float64
#  183  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_:Behandlung im Plenum.delay                          float64
#  184  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_:Änderungsantrag.delay                               float64
#  185  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_:Gesetz- und Verordnungsblatt.delay                  float64
#  186  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_:II. Lesung.delay                                    float64
#  187  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_:I. Lesung.delay                                     float64
#  188  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_:Beschlussempfehlung.delay                           float64
#  189  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_:Ausschussberatung.delay                             float64
#  190  Vorlage zur Beschlussfassung _Gesetzentwurf/Ergänzung_:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay  float64
#  191  Vorlage zur Beschlussfassung:Gesetz- und Verordnungsblatt.delay                                            float64
#  192  Vorlage zur Beschlussfassung:II. Lesung.delay                                                              float64
#  193  Vorlage zur Beschlussfassung:I. Lesung.delay                                                               float64
#  194  Vorlage zur Beschlussfassung:Beschlussempfehlung.delay                                                     float64
#  195  Vorlage zur Beschlussfassung:Ausschussberatung.delay                                                       float64
#  196  Ausschussbesprechung:Änderungsantrag.delay                                                                 float64
#  197  Ausschussbesprechung:Gesetz- und Verordnungsblatt.delay                                                    float64
#  198  Ausschussbesprechung:II. Lesung.delay                                                                      float64
#  199  Ausschussbesprechung:I. Lesung.delay                                                                       float64
#  200  Ausschussbesprechung:Beschlussempfehlung.delay                                                             float64
#  201  Ausschussbesprechung:Ausschussberatung.delay                                                               float64
#  202  Ausschussbesprechung:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                                    float64
#  203  Behandlung im Plenum:III. Lesung.delay                                                                     float64
#  204  Behandlung im Plenum:Änderungsantrag.delay                                                                 float64
#  205  Behandlung im Plenum:Gesetz- und Verordnungsblatt.delay                                                    float64
#  206  Behandlung im Plenum:II. Lesung.delay                                                                      float64
#  207  Behandlung im Plenum:Antrag _Gesetzentwurf_.delay                                                          float64
#  208  Behandlung im Plenum:I. Lesung.delay                                                                       float64
#  209  Behandlung im Plenum:Beschlussempfehlung.delay                                                             float64
#  210  Behandlung im Plenum:Ausschussberatung.delay                                                               float64
#  211  Behandlung im Plenum:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                                    float64
#  212  Bekanntmachung _Gesetz- und Verordnungsblatt_:Gesetz- und Verordnungsblatt.delay                           float64
#  213  III. Lesung:Änderungsantrag.delay                                                                          float64
#  214  III. Lesung:Gesetz- und Verordnungsblatt.delay                                                             float64
#  215  III. Lesung:II. Lesung.delay                                                                               float64
#  216  III. Lesung:I. Lesung.delay                                                                                float64
#  217  III. Lesung:Beschlussempfehlung.delay                                                                      float64
#  218  III. Lesung:Ausschussberatung.delay                                                                        float64
#  219  III. Lesung:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                                             float64
#  220  Änderungsantrag:Gesetz- und Verordnungsblatt.delay                                                         float64
#  221  Änderungsantrag:II. Lesung.delay                                                                           float64
#  222  Änderungsantrag:Antrag _Gesetzentwurf_.delay                                                               float64
#  223  Änderungsantrag:I. Lesung.delay                                                                            float64
#  224  Änderungsantrag:Beschlussempfehlung.delay                                                                  float64
#  225  Änderungsantrag:Ausschussberatung.delay                                                                    float64
#  226  Änderungsantrag:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                                         float64
#  227  Gesetz- und Verordnungsblatt:II. Lesung.delay                                                              float64
#  228  Gesetz- und Verordnungsblatt:Antrag _Gesetzentwurf_.delay                                                  float64
#  229  Gesetz- und Verordnungsblatt:I. Lesung.delay                                                               float64
#  230  Gesetz- und Verordnungsblatt:Beschlussempfehlung.delay                                                     float64
#  231  Gesetz- und Verordnungsblatt:Ausschussberatung.delay                                                       float64
#  232  Gesetz- und Verordnungsblatt:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                            float64
#  233  II. Lesung:Antrag _Gesetzentwurf_.delay                                                                    float64
#  234  II. Lesung:I. Lesung.delay                                                                                 float64
#  235  II. Lesung:Beschlussempfehlung.delay                                                                       float64
#  236  II. Lesung:Ausschussberatung.delay                                                                         float64
#  237  II. Lesung:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                                              float64
#  238  Antrag _Gesetzentwurf_:I. Lesung.delay                                                                     float64
#  239  Antrag _Gesetzentwurf_:Beschlussempfehlung.delay                                                           float64
#  240  Antrag _Gesetzentwurf_:Ausschussberatung.delay                                                             float64
#  241  I. Lesung:Beschlussempfehlung.delay                                                                        float64
#  242  I. Lesung:Ausschussberatung.delay                                                                          float64
#  243  I. Lesung:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                                               float64
#  244  Beschlussempfehlung:Ausschussberatung.delay                                                                float64
#  245  Beschlussempfehlung:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                                     float64
#  246  Ausschussberatung:Vorlage zur Beschlussfassung _Gesetzentwurf_.delay                                       float64
# dtypes: float64(241), object(6)
# memory usage: 1.0+ MB
# case_id int->float
# Gesetzentwurf.count int->float
# event_count int->float
# start_time_rel int->float
# duration int->float
# Gesetzentwurf.start int->float
# case:start_month int->float
# case:start_weekday int->float
# case:WIP_during_start int->float
# case:pdf_bytes int->float
# case:pdf_word_count int->float
# case:plenDays int->float
# case:is_election_year int->float
# case:yearly_frequency int->float
# case:yearly_variants int->float
# case:author_first_activity_landesregierung int->float
# case:author_first_activity_die linkspartei.pds _die linkspartei.pds_ int->float
# case:author_first_activity_landtag int->float
# case:author_first_activity_ausschuss int->float
# case:author_first_activity_nan int->float
# case:author_first_activity_deutsche volksunion _dvu_ int->float
# case:author_first_activity_präsidium des landtages int->float
# case:author_first_activity_fritsch, gunter _präsident des landtages brandenburg_ int->float
# case:author_first_activity_sozialdemokratische partei deutschlands _spd_ int->float
# case:author_first_activity_christlich demokratische union deutschlands _cdu_ int->float
# case:author_first_activity_die linke _die linke_ int->float
# case:author_first_activity_[.lookup error 75] _cdu_ int->float
# case:author_first_activity_fraktion bündnis 90/die grünen _b90/grüne_ int->float
# case:author_first_activity_freie demokratische partei _fdp_ int->float
# case:author_first_activity_rat für sorbische _wendische_ angelegenheiten int->float
# case:author_first_activity_bischoff, mike _spd_ int->float
# case:author_first_activity_görke, christian _die linke_ int->float
# case:author_first_activity_halem, marie luise von _b90/grüne_ int->float
# case:author_first_activity_senftleben, ingo _cdu_ int->float
# case:author_first_activity_vogdt, marion _fdp_ int->float
# case:author_first_activity_enquete-kommission 5/2 int->float
# case:author_first_activity_kircheis, kerstin _spd_ int->float
# case:author_first_activity_lipsdorf, jens _fdp_ int->float
# case:author_first_activity_maresch, jürgen _die linke_ int->float
# case:author_first_activity_schier, roswitha _cdu_ int->float
# case:author_first_activity_schierack, prof. dr. michael _cdu_ int->float
# case:author_first_activity_schippel, werner-siegwart _spd_ int->float
# case:author_first_activity_schulz-höpfner, monika _cdu_ int->float
# case:author_first_activity_wöllert, birgit _die linke_ int->float
# case:author_first_activity_domres, thomas _die linke_ int->float
# case:author_first_activity_hoffmann, dr. gerd-rüdiger _fraktionslos_ int->float
# case:author_first_activity_stark, britta _präsidentin des landtages brandenburg_ int->float
# case:author_first_activity_vida, péter _fraktionslos_ int->float
# case:author_first_activity_alternative für deutschland _afd_ int->float
# case:author_first_activity_redmann, dr. jan _cdu_ int->float
# case:author_first_activity_nonnemacher, ursula _b90/grüne_ int->float
# case:author_first_activity_brandenburger vereinigte bürgerbewegungen / freie wähler gruppe _bvb / freie wähler gruppe_ int->float
# case:author_first_activity_rat für angelegenheiten der sorben/wenden int->float
# case:author_first_activity_schulze, christoph _fraktionslos_ int->float
# case:author_first_activity_schülzke, iris _fraktionslos_ int->float
# case:author_first_activity_enquete-kommission 6/1 int->float
# case:author_first_activity_lüttmann, björn _spd_ int->float
# case:author_first_activity_bommert, frank _cdu_ int->float
# case:author_first_activity_genilke, rainer _cdu_ int->float
# case:author_first_activity_lakenmacher, björn _cdu_ int->float
# case:author_first_activity_loehr, matthias _die linke_ int->float
# case:author_first_activity_liedtke, prof. dr. ulrike _präsidentin des landtages brandenburg_ int->float
# case:author_first_activity_brandenburger vereinigte bürgerbewegungen / freie wähler gruppe _bvb/fw_ int->float
# case:author_first_activity_bretz, steeven _cdu_ int->float
# case:author_first_activity_damus, sahra _b90/grüne_ int->float
# case:author_first_activity_keller, daniel _spd_ int->float
# case:author_first_activity_schäffer, marie _b90/grüne_ int->float
# 1. Lesung.count int->float
# 1. Lesung.start int->float
# Gesetz.count int->float
# Gesetz.start int->float
# Gesetz:1. Lesung.delay int->float
# Gesetz:Gesetzentwurf.delay int->float
# 1. Lesung:Gesetzentwurf.delay int->float
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439 entries, 0 to 438
# Data columns (total 390 columns):
#  #    Column                                                                                                                  Dtype
# ---   ------                                                                                                                  -----
#  0    case_id                                                                                                                 float64
#  1    Gesetzentwurf.count                                                                                                     float64
#  2    event_count                                                                                                             float64
#  3    start_time                                                                                                              object
#  4    start_time_rel                                                                                                          float64
#  5    duration                                                                                                                float64
#  6    Gesetzentwurf.start                                                                                                     float64
#  7    case:DokTypLFirstDoc                                                                                                    object
#  8    case:VSysL                                                                                                              object
#  9    case:VorgangsDeskriptoren                                                                                               object
#  10   case:start_month                                                                                                        float64
#  11   case:start_weekday                                                                                                      float64
#  12   case:author_first_activity                                                                                              object
#  13   case:author_first_activity_count                                                                                        float64
#  14   case:WIP_during_start                                                                                                   float64
#  15   case:pdf_bytes                                                                                                          float64
#  16   case:pdf_word_count                                                                                                     float64
#  17   case:squire                                                                                                             float64
#  18   case:salary                                                                                                             float64
#  19   case:staff                                                                                                              float64
#  20   case:commDays                                                                                                           float64
#  21   case:plenDays                                                                                                           float64
#  22   case:af_score                                                                                                           float64
#  23   case:is_passed_bill                                                                                                     object
#  24   case:is_election_year                                                                                                   float64
#  25   case:yearly_frequency                                                                                                   float64
#  26   case:yearly_cycle_time                                                                                                  float64
#  27   case:yearly_arrival_rate                                                                                                float64
#  28   case:yearly_variants                                                                                                    float64
#  29   case:author_first_activity_landesregierung                                                                              float64
#  30   case:author_first_activity_die linkspartei.pds _die linkspartei.pds_                                                    float64
#  31   case:author_first_activity_landtag                                                                                      float64
#  32   case:author_first_activity_ausschuss                                                                                    float64
#  33   case:author_first_activity_nan                                                                                          float64
#  34   case:author_first_activity_deutsche volksunion _dvu_                                                                    float64
#  35   case:author_first_activity_präsidium des landtages                                                                      float64
#  36   case:author_first_activity_fritsch, gunter _präsident des landtages brandenburg_                                        float64
#  37   case:author_first_activity_sozialdemokratische partei deutschlands _spd_                                                float64
#  38   case:author_first_activity_christlich demokratische union deutschlands _cdu_                                            float64
#  39   case:author_first_activity_die linke _die linke_                                                                        float64
#  40   case:author_first_activity_[.lookup error 75] _cdu_                                                                     float64
#  41   case:author_first_activity_fraktion bündnis 90/die grünen _b90/grüne_                                                   float64
#  42   case:author_first_activity_freie demokratische partei _fdp_                                                             float64
#  43   case:author_first_activity_rat für sorbische _wendische_ angelegenheiten                                                float64
#  44   case:author_first_activity_bischoff, mike _spd_                                                                         float64
#  45   case:author_first_activity_görke, christian _die linke_                                                                 float64
#  46   case:author_first_activity_halem, marie luise von _b90/grüne_                                                           float64
#  47   case:author_first_activity_senftleben, ingo _cdu_                                                                       float64
#  48   case:author_first_activity_vogdt, marion _fdp_                                                                          float64
#  49   case:author_first_activity_enquete-kommission 5/2                                                                       float64
#  50   case:author_first_activity_kircheis, kerstin _spd_                                                                      float64
#  51   case:author_first_activity_lipsdorf, jens _fdp_                                                                         float64
#  52   case:author_first_activity_maresch, jürgen _die linke_                                                                  float64
#  53   case:author_first_activity_schier, roswitha _cdu_                                                                       float64
#  54   case:author_first_activity_schierack, prof. dr. michael _cdu_                                                           float64
#  55   case:author_first_activity_schippel, werner-siegwart _spd_                                                              float64
#  56   case:author_first_activity_schulz-höpfner, monika _cdu_                                                                 float64
#  57   case:author_first_activity_wöllert, birgit _die linke_                                                                  float64
#  58   case:author_first_activity_domres, thomas _die linke_                                                                   float64
#  59   case:author_first_activity_hoffmann, dr. gerd-rüdiger _fraktionslos_                                                    float64
#  60   case:author_first_activity_stark, britta _präsidentin des landtages brandenburg_                                        float64
#  61   case:author_first_activity_vida, péter _fraktionslos_                                                                   float64
#  62   case:author_first_activity_alternative für deutschland _afd_                                                            float64
#  63   case:author_first_activity_redmann, dr. jan _cdu_                                                                       float64
#  64   case:author_first_activity_nonnemacher, ursula _b90/grüne_                                                              float64
#  65   case:author_first_activity_brandenburger vereinigte bürgerbewegungen / freie wähler gruppe _bvb / freie wähler gruppe_  float64
#  66   case:author_first_activity_rat für angelegenheiten der sorben/wenden                                                    float64
#  67   case:author_first_activity_schulze, christoph _fraktionslos_                                                            float64
#  68   case:author_first_activity_schülzke, iris _fraktionslos_                                                                float64
#  69   case:author_first_activity_enquete-kommission 6/1                                                                       float64
#  70   case:author_first_activity_lüttmann, björn _spd_                                                                        float64
#  71   case:author_first_activity_bommert, frank _cdu_                                                                         float64
#  72   case:author_first_activity_genilke, rainer _cdu_                                                                        float64
#  73   case:author_first_activity_lakenmacher, björn _cdu_                                                                     float64
#  74   case:author_first_activity_loehr, matthias _die linke_                                                                  float64
#  75   case:author_first_activity_liedtke, prof. dr. ulrike _präsidentin des landtages brandenburg_                            float64
#  76   case:author_first_activity_brandenburger vereinigte bürgerbewegungen / freie wähler gruppe _bvb/fw_                     float64
#  77   case:author_first_activity_bretz, steeven _cdu_                                                                         float64
#  78   case:author_first_activity_damus, sahra _b90/grüne_                                                                     float64
#  79   case:author_first_activity_keller, daniel _spd_                                                                         float64
#  80   case:author_first_activity_schäffer, marie _b90/grüne_                                                                  float64
#  81   1. Lesung.count                                                                                                         float64
#  82   1. Lesung.start                                                                                                         float64
#  83   Sitzung.count                                                                                                           float64
#  84   Sitzung.start                                                                                                           float64
#  85   Beschlussempfehlung und Bericht.count                                                                                   float64
#  86   Beschlussempfehlung und Bericht.start                                                                                   float64
#  87   2. Lesung.count                                                                                                         float64
#  88   2. Lesung.start                                                                                                         float64
# ...
#  317  Bekanntmachung:Erste Beratung.delay                                                                                             float64
#  318  Bekanntmachung:Aktuelle Debatte.delay                                                                                           float64
#  319  Bekanntmachung:Gesetzentwurf.delay                                                                                              float64
#  320  Dritte Beratung:Beschluss des Landtags in Zweiter Beratung.delay                                                                float64
#  321  Dritte Beratung:Änderungs- und Entschließungsanträge _Sammeldrucksache_.delay                                                   float64
#  322  Dritte Beratung:Vorschlag.delay                                                                                                 float64
#  323  Dritte Beratung:Gesetz.delay                                                                                                    float64
#  324  Dritte Beratung:Gesetzesbeschluss des Landtags.delay                                                                            float64
#  325  Dritte Beratung:Zweite Beratung.delay                                                                                           float64
#  326  Dritte Beratung:Änderungsantrag.delay                                                                                           float64
#  327  Dritte Beratung:Änderungsanträge _Sammeldrucksache_.delay                                                                       float64
#  328  Dritte Beratung:Mitteilung.delay                                                                                                float64
#  329  Dritte Beratung:Beschlussempfehlung und Bericht.delay                                                                           float64
#  330  Dritte Beratung:Erste Beratung.delay                                                                                            float64
#  331  Dritte Beratung:Aktuelle Debatte.delay                                                                                          float64
#  332  Dritte Beratung:Gesetzentwurf.delay                                                                                             float64
#  333  Beschluss des Landtags in Zweiter Beratung:Änderungs- und Entschließungsanträge _Sammeldrucksache_.delay                        float64
#  334  Beschluss des Landtags in Zweiter Beratung:Vorschlag.delay                                                                      float64
#  335  Beschluss des Landtags in Zweiter Beratung:Gesetz.delay                                                                         float64
#  336  Beschluss des Landtags in Zweiter Beratung:Gesetzesbeschluss des Landtags.delay                                                 float64
#  337  Beschluss des Landtags in Zweiter Beratung:Zweite Beratung.delay                                                                float64
#  338  Beschluss des Landtags in Zweiter Beratung:Änderungsantrag.delay                                                                float64
#  339  Beschluss des Landtags in Zweiter Beratung:Änderungsanträge _Sammeldrucksache_.delay                                            float64
#  340  Beschluss des Landtags in Zweiter Beratung:Mitteilung.delay                                                                     float64
#  341  Beschluss des Landtags in Zweiter Beratung:Beschlussempfehlung und Bericht.delay                                                float64
#  342  Beschluss des Landtags in Zweiter Beratung:Erste Beratung.delay                                                                 float64
#  343  Beschluss des Landtags in Zweiter Beratung:Aktuelle Debatte.delay                                                               float64
#  344  Beschluss des Landtags in Zweiter Beratung:Gesetzentwurf.delay                                                                  float64
#  345  Antrag:Änderungs- und Entschließungsanträge _Sammeldrucksache_.delay                                                            float64
#  346  Antrag:Gesetz.delay                                                                                                             float64
#  347  Antrag:Gesetzesbeschluss des Landtags.delay                                                                                     float64
#  348  Antrag:Zweite Beratung.delay                                                                                                    float64
#  349  Antrag:Änderungsantrag.delay                                                                                                    float64
#  350  Antrag:Mitteilung.delay                                                                                                         float64
#  351  Antrag:Beschlussempfehlung und Bericht.delay                                                                                    float64
#  352  Antrag:Erste Beratung.delay                                                                                                     float64
#  353  Antrag:Gesetzentwurf.delay                                                                                                      float64
#  354  Änderungs- und Entschließungsanträge _Sammeldrucksache_:Vorschlag.delay                                                         float64
#  355  Änderungs- und Entschließungsanträge _Sammeldrucksache_:Gesetz.delay                                                            float64
#  356  Änderungs- und Entschließungsanträge _Sammeldrucksache_:Gesetzesbeschluss des Landtags.delay                                    float64
#  357  Änderungs- und Entschließungsanträge _Sammeldrucksache_:Zweite Beratung.delay                                                   float64
#  358  Änderungs- und Entschließungsanträge _Sammeldrucksache_:Änderungsantrag.delay                                                   float64
#  359  Änderungs- und Entschließungsanträge _Sammeldrucksache_:Änderungsanträge _Sammeldrucksache_.delay                               float64
#  360  Änderungs- und Entschließungsanträge _Sammeldrucksache_:Mitteilung.delay                                                        float64
#  361  Änderungs- und Entschließungsanträge _Sammeldrucksache_:Beschlussempfehlung und Bericht.delay                                   float64
#  362  Änderungs- und Entschließungsanträge _Sammeldrucksache_:Erste Beratung.delay                                                    float64
#  363  Änderungs- und Entschließungsanträge _Sammeldrucksache_:Aktuelle Debatte.delay                                                  float64
#  364  Änderungs- und Entschließungsanträge _Sammeldrucksache_:Gesetzentwurf.delay                                                     float64
#  365  Gesetzblatt für Baden-Württemberg:Vorschlag.delay                                                                               float64
#  366  Gesetzblatt für Baden-Württemberg:Gesetz.delay                                                                                  float64
#  367  Gesetzblatt für Baden-Württemberg:Gesetzesbeschluss des Landtags.delay                                                          float64
#  368  Gesetzblatt für Baden-Württemberg:Zweite Beratung.delay                                                                         float64
#  369  Gesetzblatt für Baden-Württemberg:Änderungsantrag.delay                                                                         float64
#  370  Gesetzblatt für Baden-Württemberg:Änderungsanträge _Sammeldrucksache_.delay                                                     float64
#  371  Gesetzblatt für Baden-Württemberg:Beschlussempfehlung und Bericht.delay                                                         float64
#  372  Gesetzblatt für Baden-Württemberg:Erste Beratung.delay                                                                          float64
#  373  Gesetzblatt für Baden-Württemberg:Aktuelle Debatte.delay                                                                        float64
#  374  Gesetzblatt für Baden-Württemberg:Gesetzentwurf.delay                                                                           float64
#  375  Vorschlag:Gesetz.delay                                                                                                          float64
#  376  Vorschlag:Gesetzesbeschluss des Landtags.delay                                                                                  float64
#  377  Vorschlag:Zweite Beratung.delay                                                                                                 float64
#  378  Vorschlag:Änderungsantrag.delay                                                                                                 float64
#  379  Vorschlag:Änderungsanträge _Sammeldrucksache_.delay                                                                             float64
#  380  Vorschlag:Mitteilung.delay                                                                                                      float64
#  381  Vorschlag:Beschlussempfehlung und Bericht.delay                                                                                 float64
#  382  Vorschlag:Erste Beratung.delay                                                                                                  float64
#  383  Vorschlag:Aktuelle Debatte.delay                                                                                                float64
#  384  Vorschlag:Gesetzentwurf.delay                                                                                                   float64
#  385  Gesetz:Gesetzesbeschluss des Landtags.delay                                                                                     float64
#  386  Gesetz:Zweite Beratung.delay                                                                                                    float64
#  387  Gesetz:Änderungsantrag.delay                                                                                                    float64
#  388  Gesetz:Änderungsanträge _Sammeldrucksache_.delay                                                                                float64
#  389  Gesetz:Mitteilung.delay                                                                                                         float64
#  390  Gesetz:Beschlussempfehlung und Bericht.delay                                                                                    float64
#  391  Gesetz:Erste Beratung.delay                                                                                                     float64
#  392  Gesetz:Aktuelle Debatte.delay                                                                                                   float64
#  393  Gesetz:Gesetzentwurf.delay                                                                                                      float64
#  394  Gesetzesbeschluss des Landtags:Zweite Beratung.delay                                                                            float64
#  395  Gesetzesbeschluss des Landtags:Änderungsantrag.delay                                                                            float64
#  396  Gesetzesbeschluss des Landtags:Änderungsanträge _Sammeldrucksache_.delay                                                        float64
#  397  Gesetzesbeschluss des Landtags:Mitteilung.delay                                                                                 float64
#  398  Gesetzesbeschluss des Landtags:Beschlussempfehlung und Bericht.delay                                                            float64
#  399  Gesetzesbeschluss des Landtags:Erste Beratung.delay                                                                             float64
#  400  Gesetzesbeschluss des Landtags:Aktuelle Debatte.delay                                                                           float64
#  401  Gesetzesbeschluss des Landtags:Gesetzentwurf.delay                                                                              float64
#  402  Zweite Beratung:Änderungsantrag.delay                                                                                           float64
#  403  Zweite Beratung:Änderungsanträge _Sammeldrucksache_.delay                                                                       float64
#  404  Zweite Beratung:Mitteilung.delay                                                                                                float64
#  405  Zweite Beratung:Beschlussempfehlung und Bericht.delay                                                                           float64
#  406  Zweite Beratung:Erste Beratung.delay                                                                                            float64
#  407  Zweite Beratung:Aktuelle Debatte.delay                                                                                          float64
#  408  Zweite Beratung:Gesetzentwurf.delay                                                                                             float64
#  409  Änderungsantrag:Änderungsanträge _Sammeldrucksache_.delay                                                                       float64
#  410  Änderungsantrag:Mitteilung.delay                                                                                                float64
#  411  Änderungsantrag:Beschlussempfehlung und Bericht.delay                                                                           float64
#  412  Änderungsantrag:Erste Beratung.delay                                                                                            float64
#  413  Änderungsantrag:Aktuelle Debatte.delay                                                                                          float64
#  414  Änderungsantrag:Gesetzentwurf.delay                                                                                             float64
#  415  Änderungsanträge _Sammeldrucksache_:Beschlussempfehlung und Bericht.delay                                                       float64
#  416  Änderungsanträge _Sammeldrucksache_:Erste Beratung.delay                                                                        float64
#  417  Änderungsanträge _Sammeldrucksache_:Aktuelle Debatte.delay                                                                      float64
#  418  Änderungsanträge _Sammeldrucksache_:Gesetzentwurf.delay                                                                         float64
#  419  Mitteilung:Beschlussempfehlung und Bericht.delay                                                                                float64
#  420  Mitteilung:Erste Beratung.delay                                                                                                 float64
#  421  Mitteilung:Aktuelle Debatte.delay                                                                                               float64
#  422  Mitteilung:Gesetzentwurf.delay                                                                                                  float64
#  423  Beschlussempfehlung und Bericht:Erste Beratung.delay                                                                            float64
#  424  Beschlussempfehlung und Bericht:Aktuelle Debatte.delay                                                                          float64
#  425  Beschlussempfehlung und Bericht:Gesetzentwurf.delay                                                                             float64
#  426  Erste Beratung:Aktuelle Debatte.delay                                                                                           float64
#  427  Erste Beratung:Gesetzentwurf.delay                                                                                              float64
#  428  Aktuelle Debatte:Gesetzentwurf.delay                                                                                            float64
# dtypes: float64(423), object(6)
# memory usage: 1.0+ MB

# %%
# Prep data: Imputation whenever needed
for df in [df_berlin, df_brandenburg, df_baWue]:
    for column in df.select_dtypes(include=['object']).columns:
        df[column] = df[column].fillna(STRING_IMPUTE_VAL)  # normalize missing string values
    if ALGO in ['CART:4'] or BINA in ['TREES']:
        for column in df.select_dtypes(include=['float64']).columns:
            df[column] = df[column].fillna(FLOAT_IMPUTE_VAL)

# %% [markdown]
# ## Configuration of the Explanation Problem

# %%
POS_CLASS = True
df_berlin['outcome'] = df_berlin.apply(outcome, axis=1)
df_brandenburg['outcome'] = df_brandenburg.apply(outcome, axis=1)
df_baWue['outcome'] = df_baWue.apply(outcome, axis=1)

# %% [markdown]
# ### Attribute Hiding

# %%
# Use attribute names or regular expressions to hide
HIDE = [
    
    # hide what we want to explain
    'duration',
    r'.*cycle.*',
    
    # hide meaningless columns
    'case_id',
    r'.*none.*',
    r'.*nan.*',
    

        
    # temporal columns
    'start_time_rel',
    'start_time', 
    r'.*start.*', 
    #r'.*delay.*',
    
    r'.*Geset.*',

    # experiments
    #r'.*count.*',

    #"is_passed_bill",
    
    #r'.*:[0-9].*',

    ]

for df in [df_berlin, df_brandenburg, df_baWue]:
    for pattern in HIDE:
        for col in df.columns:
            if re.fullmatch(pattern, col):
                # print('Dropping {} on pattern "{}".'.format(col, pattern))
                df.drop(columns=[col], inplace=True)

# %% [markdown]
# ## Run Rule Induction

# %%
stateParliaments = ['Berlin', 'Brandenburg', 'BaWue']
for index, df in enumerate([df_berlin, df_brandenburg, df_baWue]):    
    print(f"\nHandling dataset: {stateParliaments[index]}\n")
    
    # Prep data: Split into training and test set
    if TRAIN_TEST_SPLIT > 0.0:
        x_train, x_test, y_train, y_test = train_test_split(
            df.drop(columns=['outcome']),
            df['outcome'],
            test_size=TRAIN_TEST_SPLIT,
            random_state=3) 
    else:
        x_train = df.drop(columns=['outcome'])
        y_train = df['outcome']
        x_test = x_train
        y_test = y_train
    
    
    # Run Binarizer / Encoding
    if BINA == 'LENC':
        x_train_bin = x_train
        x_test_bin = x_test
        categorical_features = x_train_bin.select_dtypes(include=['object']).columns
        for col in categorical_features:
            label_encoder = LabelEncoder()
            label_encoder = label_encoder.fit(df[col])
            x_train_bin[col] = label_encoder.transform(x_train_bin[col])
            x_test_bin[col] = label_encoder.transform(x_test_bin[col])
            print(col, label_encoder.classes_, label_encoder.transform(label_encoder.classes_))
    elif BINA == 'NATIVE':
        x_train_bin = x_train.copy() # RIPPER implementation messes with the training set
        x_test_bin = x_test
        
    if ALGO == 'RIPPER':
        estimator = RipperExplainer()
        estimator.fit(x_train_bin, y_train, target_label=POS_CLASS)
    else:
        print('Not supported.')
        
    
    # Evaluation
    y_predicted = estimator.predict(x_test_bin)
    # print('Accuracy:', round(accuracy_score(y_test, y_predicted), 2))
    print('Predictive:')
    print('Precision:', round(precision_score(y_test, y_predicted, pos_label=POS_CLASS, zero_division=1), 6))
    print('Recall:', round(recall_score(y_test, y_predicted, pos_label=POS_CLASS), 6))
    y_predicted_train = estimator.predict(x_train_bin)
    print('Descriptive:')
    print('Precision:', round(precision_score(y_train, y_predicted_train, pos_label=POS_CLASS, zero_division=1), 6))
    print('Recall:', round(recall_score(y_train, y_predicted_train, pos_label=POS_CLASS), 6))
    
    

    # Model export
    print("bawue_average_cycle_time_upper_bound:", bawue_average_cycle_time_upper_bound)
    if ALGO in ('RIPPER'):
        rule_set = estimator.explain()
        print(rule_set)
# Out:
# Handling dataset: Berlin
#
# Predictive:
# Precision: 0.866667
# Recall: 0.928571
# Descriptive:
# Precision: 0.947619
# Recall: 0.943128
# bawue_average_cycle_time_upper_bound: 100.68525641025641
# if
# ([II. Lesung:I. Lesung.delay <= -97.0]) v
# ([II. Lesung:I. Lesung.delay <= -83.0]) v
# ([I. Lesung:Ausschussberatung.delay >= 18.0] ^ [II. Lesung:I. Lesung.delay <= -69.0] ^ [case:pdf_word_count >= 13742.0]) v
# ([I. Lesung:Ausschussberatung.delay >= 18.0] ^ [II. Lesung:I. Lesung.delay <= -69.0] ^ [case:yearly_arrival_rate <= 5.91] ^ [event_count >= 7.0] ^ [case:DokTypLFirstDoc == Vorlage zur Beschlussfassung (Gesetzentwurf)]) v
# ([II. Lesung:Beschlussempfehlung.delay <= -16.0] ^ [case:plenDays >= 27.0] ^ [case:pdf_word_count >= 1733.0]) v
# ([event_count >= 7.0] ^ [Ausschussberatung.count <= 1.0] ^ [Änderungsantrag.count <= 0.0]) v
# ([event_count >= 8.0] ^ [Ausschussberatung.count <= 2.0] ^ [Änderungsantrag.count <= 0.0] ^ [case:yearly_frequency <= 59.0]) v
# ([case:yearly_variants >= 38.0] ^ [case:pdf_bytes >= 2222845.0]) v
# ([case:VSysL == Rundfunk, Fernsehen]) v
# ([event_count >= 8.0] ^ [I. Lesung:Ausschussberatung.delay >= 34.0] ^ [I. Lesung:Ausschussberatung.delay <= 39.0]) v
# ([case:VSysL == ['Innere Sicherheit', 'Ausländer Vertriebene Aus- und Übersiedler']]) v
# ([II. Lesung:Ausschussberatung.delay <= -16.0] ^ [case:yearly_frequency <= 23.0] ^ [II. Lesung:I. Lesung.delay <= -69.0]) v
# ([case:VorgangsDeskriptoren == ['Gesundheitsstatistik', 'Meldewesen', 'Ostdeutsche Länder', 'Staatsvertrag']]) v
# ([case:VorgangsDeskriptoren == ['Kreditaufnahme', 'Landeshaushaltsordnung']])
# then
# True
#
# Handling dataset: Brandenburg
#
# Predictive:
# Precision: 0.941176
# Recall: 0.941176
# Descriptive:
# Precision: 0.928302
# Recall: 0.987952
# bawue_average_cycle_time_upper_bound: 100.68525641025641
# if
# ([2. Lesung:1. Lesung.delay <= -75.0] ^ [case:yearly_frequency <= 59.0]) v
# ([Bekanntmachung:Beschlussempfehlung und Bericht.delay <= -49.0]) v
# ([2. Lesung:1. Lesung.delay <= -91.0] ^ [case:pdf_bytes >= 12224.0]) v
# ([2. Lesung:1. Lesung.delay <= -69.0]) v
# ([2. Lesung:Sitzung.delay <= -97.0]) v
# ([case:VSysL == ['Umwelt', 'Bauwesen']]) v
# ([case:VSysL == ['Öffentliche Verwaltung', 'Informations- und Kommunikationstechnologien']]) v
# ([case:VorgangsDeskriptoren == ['Hochschule', 'Staatsvertrag über die Errichtung einer gemeinsamen Einrichtung für Hochschulzulassung', 'Staatsvertrag', 'Stiftung für Hochschulzulassung', 'Stiftung', 'Studiengang', 'Studienplatz', 'Vergabeverfahren', 'Zentralstelle der Länder zur Vergabe von Studienplätzen', 'Zulassungsbeschränkung an Hochschulen']])
# then
# True
#
# Handling dataset: BaWue
#
# Predictive:
# Precision: 1.0
# Recall: 0.666667
# Descriptive:
# Precision: 0.984615
# Recall: 0.901408
# bawue_average_cycle_time_upper_bound: 100.68525641025641
# if
# ([Zweite Beratung:Erste Beratung.delay <= -69.0] ^ [case:pdf_bytes <= 130703.0] ^ [case:author_first_activity_count <= 2.0]) v
# ([Bekanntmachung:Beschlussempfehlung und Bericht.delay <= -82.0]) v
# ([Beschlussempfehlung und Bericht:Erste Beratung.delay <= -48.0] ^ [Änderungsantrag.count <= 0.0] ^ [case:pdf_word_count >= 2674.0] ^ [case:pdf_bytes <= 1171327.0]) v
# ([Bekanntmachung über das Inkrafttreten:Zweite Beratung.delay <= -86.0]) v
# ([Zweite Beratung:Mitteilung.delay >= 69.0]) v
# ([Zweite Beratung:Erste Beratung.delay <= -42.0] ^ [case:VSysL == Öffentlicher Dienst] ^ [event_count <= 8.0]) v
# ([Beschlussempfehlung und Bericht:Erste Beratung.delay <= -35.0] ^ [case:pdf_word_count >= 10309.0] ^ [case:pdf_word_count <= 11072.0]) v
# ([case:pdf_word_count >= 14451.0] ^ [case:squire <= 0.3562977661267577] ^ [case:pdf_bytes >= 137308.0]) v
# ([case:af_score >= 0.151758853363511] ^ [Änderungsanträge _Sammeldrucksache_:Erste Beratung.delay >= -27.0] ^ [case:pdf_word_count >= 7923.0]) v
# ([case:af_score >= 0.151758853363511] ^ [Beschlussempfehlung und Bericht:Erste Beratung.delay <= -36.0] ^ [event_count >= 7.0] ^ [event_count <= 9.0]) v
# ([case:VSysL == ['Öffentliche Verwaltung', 'Wirtschaft']]) v
# ([case:VorgangsDeskriptoren == ['Anwärterauflagenverordnung', 'Arbeitszeit- und Urlaubsverordnung', 'Beamtenrechtszuständigkeitsverordnung', 'Dienstfahrzeug', 'Erschwerniszulagenverordnung Baden-Württemberg', 'Fahrrad', 'Kommunale Gebietskörperschaft', 'Landesbeamtengesetz', 'Landesbesoldungsgesetz Baden-Württemberg', 'Leistungsbezügeverordnung', 'Stellenobergrenzenverordnung', 'Stellenplan', 'Verordnung der Landesregierung und des Finanzministeriums über die Zuständigkeiten des Landesamtes für Besoldung und Versorgung Baden-Württemberg']]) v
# ([case:VorgangsDeskriptoren == ['Bürokratieabbau', 'Fisch']]) v
# ([case:VorgangsDeskriptoren == ['Flagge', 'Staatssymbol', 'Wappen']])
# then
# True
